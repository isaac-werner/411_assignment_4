# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
import itertools
import time


def apriori_frequent_item_sets(data_frame, min_support, max_len):
item_set_dict = {}
all_ms = set()
for i in range(1, 100):
    all_ms.add(f'M{i}')

item_sets = []
item_set_1 = set()
for m in all_ms:
    count = 0
    for index, row in data_frame.iterrows():
        if row[m]:
            count += 1
    if count >= min_support:
        item_set_1.add(m)
        item_set_dict[f'(\'{m}\')'] = count

item_sets.append(item_set_1)
for i in range(1, max_len):
    all_entries = set()
    if i == 1:
        for m in item_sets[0]:
            all_entries.add(m)
    else:
        for ms in item_sets[i - 1]:
            all_entries.update(ms)

    sub_sets = set(itertools.combinations(all_entries, i + 1))
    item_set = []
    h = 1
    for sub_set in sub_sets:
        h += 1
        count = 0
        in_row = False
        for index, row in data_frame.iterrows():
            for m in sub_set:
                if row[m]:
                    in_row = True
                else:
                    in_row = False
                    break
            if in_row:
                count += 1
        if count >= min_support:
            item_set.append(sub_set)
            item_set_dict[str(sub_set)] = count
    item_sets.append(item_set)

for key in item_set_dict.keys():
    print(f'{key} {item_set_dict[key]}')

# %%
start_time = time.time()
df = pd.read_csv('transactionlarge.csv', header=None)

data_set = []
for index, row in df.iterrows():
    data_row = []
    for value in row.values:
        if str(value) != 'nan':
            data_row.append(value)
    data_set.append(data_row)

te = TransactionEncoder()
te_array = te.fit(data_set).transform(data_set)

data_frame = pd.DataFrame(te_array, columns=te.columns_)
apriori_frequent_item_sets(data_frame, 3, 3)
print(f'Runtime: {time.time() - start_time} seconds')
# Out:
# ('M5', 'M27') 6
# ('M35', 'M29') 5
# ('M69', 'M27') 4
# ('M24', 'M78') 4
# ('M32', 'M31') 5
# ('M22', 'M29') 5
# ('M23', 'M8') 3
# ('M66', 'M87') 7
# ('M89', 'M78') 4
# ('M38', 'M90') 3
# ('M20', 'M12') 3
# ('M63', 'M31') 3
# ('M26', 'M73') 5
# ('M36', 'M42') 3
# ('M45', 'M28') 3
# ('M91', 'M30') 3
# ('M41', 'M50') 3
# ('M56', 'M61') 4
# ('M10', 'M56') 5
# ('M98', 'M48') 4
# ('M5', 'M25') 4
# ('M54', 'M70') 4
# ('M67', 'M72') 3
# ('M98', 'M2') 11
# ('M46', 'M15') 3
# ('M69', 'M60') 3
# ('M37', 'M18') 3
# ('M33', 'M24') 4
# ('M45', 'M91') 4
# ('M45', 'M11') 3
# ('M60', 'M10') 4
# ('M47', 'M19') 3
# ('M24', 'M68') 3
# ('M79', 'M99') 3
# ('M28', 'M97') 4
# ('M80', 'M10') 3
# ('M62', 'M30') 4
# ('M45', 'M67') 4
# ('M67', 'M14') 4
# ('M14', 'M7') 4
# ('M45', 'M41') 3
# ('M56', 'M66') 4
# ('M84', 'M87') 5
# ('M71', 'M8') 3
# ('M73', 'M15') 6
# ('M61', 'M84') 4
# ('M65', 'M70') 4
# ('M74', 'M58') 3
# ('M61', 'M12') 3
# ('M45', 'M1') 3
# ('M6', 'M35') 6
# ('M21', 'M15') 4
# ('M62', 'M45') 7
# ('M22', 'M83') 3
# ('M50', 'M53') 4
# ('M84', 'M16') 4
# ('M78', 'M57') 3
# ('M61', 'M48') 5
# ('M5', 'M8') 4
# ('M94', 'M91') 3
# ('M52', 'M68') 3
# ('M99', 'M70') 3
# ('M12', 'M92') 4
# ('M66', 'M63') 3
# ('M59', 'M99') 3
# ('M28', 'M15') 6
# ('M79', 'M92') 3
# ('M37', 'M36') 3
# ('M51', 'M79') 6
# ('M51', 'M89') 3
# ('M19', 'M73') 3
# ('M1', 'M2') 8
# ('M37', 'M35') 4
# ('M80', 'M32') 3
# ('M33', 'M78') 4
# ('M74', 'M99') 3
# ('M56', 'M35') 3
# ('M53', 'M83') 5
# ('M50', 'M78') 3
# ('M14', 'M50') 4
# ('M35', 'M15') 3
# ('M22', 'M15') 6
# ('M60', 'M27') 6
# ('M69', 'M7') 3
# ('M66', 'M55') 3
# ('M14', 'M29') 3
# ('M80', 'M27') 3
# ('M13', 'M29') 3
# ('M56', 'M31') 3
# ('M53', 'M11') 3
# ('M10', 'M53') 3
# ('M14', 'M77') 4
# ('M81', 'M16') 3
# ('M37', 'M47') 4
# ('M93', 'M96') 3
# ('M60', 'M78') 3
# ('M24', 'M75') 3
# ('M50', 'M9') 3
# ('M89', 'M46') 6
# ('M80', 'M78') 6
# ('M38', 'M32') 6
# ('M5', 'M46') 6
# ('M40', 'M35') 3
# ('M59', 'M98') 3
# ('M50', 'M68') 7
# ('M68', 'M1') 3
# ('M68', 'M15') 4
# ('M60', 'M25') 5
# ('M84', 'M30') 5
# ('M97', 'M29') 3
# ('M51', 'M87') 4
# ('M33', 'M51') 4
# ('M48', 'M11') 5
# ('M91', 'M32') 6
# ('M38', 'M94') 4
# ('M9', 'M92') 3
# ('M38', 'M27') 6
# ('M90', 'M1') 4
# ('M33', 'M22') 3
# ('M28', 'M81') 3
# ('M20', 'M53') 4
# ('M55', 'M57') 3
# ('M25', 'M30') 7
# ('M80', 'M9') 6
# ('M79', 'M11') 3
# ('M84', 'M55') 4
# ('M89', 'M73') 8
# ('M25', 'M4') 3
# ('M57', 'M73') 5
# ('M24', 'M29') 4
# ('M6', 'M58') 3
# ('M60', 'M68') 5
# ('M5', 'M73') 3
# ('M8', 'M15') 8
# ('M69', 'M50') 4
# ('M91', 'M35') 4
# ('M37', 'M8') 4
# ('M24', 'M77') 3
# ('M38', 'M78') 4
# ('M88', 'M48') 3
# ('M62', 'M32') 5
# ('M98', 'M17') 4
# ('M9', 'M98') 3
# ('M45', 'M89') 7
# ('M13', 'M83') 5
# ('M25', 'M55') 3
# ('M88', 'M2') 6
# ('M52', 'M86') 3
# ('M99', 'M63') 4
# ('M69', 'M29') 4
# ('M59', 'M28') 6
# ('M10', 'M31') 3
# ('M37', 'M52') 4
# ('M67', 'M16') 3
# ('M5', 'M77') 4
# ('M52', 'M73') 3
# ('M72', 'M55') 3
# ('M59', 'M93') 3
# ('M69', 'M77') 5
# ('M38', 'M88') 3
# ('M23', 'M11') 3
# ('M62', 'M35') 4
# ('M74', 'M42') 3
# ('M99', 'M84') 4
# ('M50', 'M7') 3
# ('M62', 'M27') 3
# ('M18', 'M84') 5
# ('M65', 'M2') 3
# ('M52', 'M29') 4
# ('M59', 'M91') 4
# ('M90', 'M3') 3
# ('M54', 'M56') 3
# ('M74', 'M28') 5
# ('M61', 'M53') 4
# ('M52', 'M77') 3
# ('M97', 'M83') 4
# ('M93', 'M2') 4
# ('M41', 'M72') 4
# ('M93', 'M6') 5
# ('M11', 'M15') 4
# ('M38', 'M68') 3
# ('M18', 'M2') 3
# ('M62', 'M5', 'M93') 3
# ('M37', 'M10', 'M53') 3
# ('M60', 'M25', 'M92') 3
# ('M61', 'M68', 'M15') 3
# ('M9', 'M66', 'M25') 4
# ('M61', 'M20', 'M53') 3
# ('M23', 'M50', 'M27') 4
# ('M37', 'M72', 'M83') 5
# ('M59', 'M80', 'M56') 3
# ('M47', 'M70', 'M3') 4
# ('M37', 'M41', 'M70') 3
# ('M79', 'M98', 'M29') 5
# ('M37', 'M51', 'M41') 3
# ('M9', 'M73', 'M16') 5
# ('M18', 'M25', 'M32') 4
# ('M17', 'M11', 'M6') 7
# ('M98', 'M2', 'M35') 3
# ('M47', 'M72', 'M92') 3
# ('M24', 'M10', 'M72') 5
# ('M69', 'M27', 'M6') 3
# ('M10', 'M71', 'M88') 3
# ('M45', 'M71', 'M8') 3
# ('M61', 'M17', 'M43') 5
# ('M10', 'M68', 'M1') 3
# ('M9', 'M11', 'M2') 4
# ('M63', 'M53', 'M35') 5
# ('M65', 'M9', 'M66') 3
# ('M77', 'M2', 'M29') 5
# ('M27', 'M78', 'M6') 3
# ('M74', 'M89', 'M84') 3
# ('M76', 'M99', 'M3') 3
# ('M50', 'M12', 'M6') 3
# ('M22', 'M89', 'M46') 5
# ('M65', 'M56', 'M78') 3
# ('M65', 'M9', 'M73') 5
# ('M77', 'M6', 'M35') 5
# ('M17', 'M11', 'M2') 4
# ('M79', 'M98', 'M2') 5
# ('M69', 'M7', 'M35') 3
# ('M63', 'M87', 'M35') 5
# ('M59', 'M80', 'M84') 3
# ('M74', 'M10', 'M87') 3
# ('M69', 'M6', 'M35') 5
# ('M37', 'M10', 'M2') 3
# ('M65', 'M66', 'M3') 3
# ('M9', 'M91', 'M29') 3
# ('M14', 'M93', 'M91') 3
# ('M60', 'M48', 'M11') 3
# ('M51', 'M10', 'M95') 3
# ('M45', 'M38', 'M84') 3
# ('M37', 'M61', 'M43') 3
# ('M13', 'M70', 'M2') 3
# ('M37', 'M74', 'M72') 4
# ('M28', 'M66', 'M25') 5
# ('M45', 'M72', 'M73') 3
# ('M79', 'M98', 'M77') 5
# ('M80', 'M28', 'M66') 6
# ('M71', 'M32', 'M15') 3
# ('M37', 'M3', 'M29') 3
# ('M37', 'M22', 'M9') 3
# ('M45', 'M73', 'M29') 3
# ('M68', 'M87', 'M3') 5
# ('M65', 'M66', 'M16') 3
# ('M80', 'M67', 'M78') 3
# ('M37', 'M70', 'M3') 3
# ('M37', 'M47', 'M72') 3
# ('M38', 'M18', 'M32') 5
# ('M61', 'M98', 'M2') 3
# ('M9', 'M91', 'M27') 5
# ('M28', 'M57', 'M3') 3
# ('M98', 'M77', 'M2') 6
# ('M76', 'M71', 'M78') 3
# ('M56', 'M50', 'M68') 5
# ('M50', 'M84', 'M92') 3
# ('M93', 'M9', 'M27') 3
# ('M60', 'M14', 'M53') 6
# ('M9', 'M25', 'M30') 3
# ('M37', 'M27', 'M83') 3
# ('M61', 'M91', 'M15') 3
# ('M37', 'M9', 'M3') 3
# ('M38', 'M67', 'M32') 5
# ('M59', 'M56', 'M15') 5
# ('M60', 'M50', 'M68') 5
# ('M98', 'M77', 'M29') 5
# ('M71', 'M93', 'M32') 3
# ('M77', 'M35', 'M73') 3
# ('M62', 'M38', 'M29') 5
# ('M9', 'M66', 'M30') 3
# ('M44', 'M80', 'M84') 3
# ('M14', 'M22', 'M15') 3
# ('M56', 'M50', 'M92') 5
# ('M24', 'M72', 'M83') 5
# ('M74', 'M68', 'M2') 3
# ('M38', 'M84', 'M32') 5
# ('M76', 'M71', 'M15') 3
# ('M80', 'M9', 'M66') 4
# ('M66', 'M92', 'M87') 5
# ('M56', 'M5', 'M46') 3
# ('M74', 'M78', 'M63') 3
# ('M12', 'M63', 'M35') 3
# ('M45', 'M5', 'M73') 3
# ('M14', 'M91', 'M15') 3
# ('M45', 'M57', 'M73') 3
# ('M74', 'M10', 'M2') 3
# ('M72', 'M53', 'M87') 5
# ('M12', 'M6', 'M35') 5
# ('M37', 'M9', 'M16') 3
# ('M10', 'M61', 'M32') 3
# ('M18', 'M84', 'M31') 3
# ('M65', 'M3', 'M16') 5
# ('M59', 'M56', 'M78') 5
# ('M14', 'M9', 'M27') 6
# ('M50', 'M68', 'M84') 3
# ('M98', 'M87', 'M2') 3
# ('M45', 'M93', 'M29') 5
# ('M72', 'M63', 'M35') 5
# ('M61', 'M11', 'M43') 5
# ('M59', 'M80', 'M3') 3
# ('M28', 'M7', 'M78') 3
# ('M59', 'M66', 'M3') 3
# ('M62', 'M93', 'M91') 3
# ('M45', 'M61', 'M15') 3
# ('M37', 'M74', 'M87') 3
# ('M28', 'M66', 'M57') 3
# ('M79', 'M71', 'M92') 3
# ('M67', 'M32', 'M31') 4
# ('M60', 'M14', 'M27') 3
# ('M37', 'M24', 'M38') 3
# ('M68', 'M92', 'M87') 5
# ('M74', 'M47', 'M72') 5
# ('M59', 'M78', 'M3') 5
# ('M64', 'M11', 'M2') 3
# ('M23', 'M27', 'M55') 3
# ('M28', 'M78', 'M57') 3
# ('M71', 'M56', 'M21') 3
# ('M61', 'M8', 'M98') 3
# ('M60', 'M36', 'M48') 3
# ('M14', 'M48', 'M84') 5
# ('M5', 'M93', 'M32') 5
# ('M23', 'M55', 'M2') 3
# ('M59', 'M80', 'M16') 3
# ('M61', 'M17', 'M15') 3
# ('M45', 'M70', 'M15') 5
# ('M61', 'M98', 'M1') 3
# ('M18', 'M61', 'M32') 3
# ('M59', 'M9', 'M66') 3
# ('M80', 'M65', 'M73') 3
# ('M93', 'M17', 'M27') 3
# ('M59', 'M99', 'M56') 3
# ('M60', 'M50', 'M92') 5
# ('M8', 'M1', 'M15') 3
# ('M28', 'M66', 'M30') 5
# ('M24', 'M78', 'M2') 3
# ('M24', 'M3', 'M29') 3
# ('M80', 'M84', 'M16') 3
# ('M68', 'M66', 'M78') 3
# ('M41', 'M8', 'M15') 4
# ('M91', 'M66', 'M3') 3
# ('M66', 'M87', 'M3') 5
# ('M89', 'M84', 'M73') 6
# ('M74', 'M10', 'M8') 3
# ('M10', 'M72', 'M83') 5
# ('M84', 'M25', 'M83') 3
# ('M60', 'M50', 'M20') 3
# ('M59', 'M28', 'M78') 3
# ('M14', 'M9', 'M17') 3
# ('M23', 'M71', 'M15') 3
# ('M7', 'M93', 'M27') 3
# ('M45', 'M8', 'M63') 4
# ('M17', 'M63', 'M11') 3
# ('M71', 'M22', 'M98') 3
# ('M28', 'M25', 'M30') 5
# ('M65', 'M66', 'M73') 3
# ('M37', 'M74', 'M2') 3
# ('M44', 'M74', 'M84') 3
# ('M24', 'M3', 'M2') 4
# ('M7', 'M22', 'M93') 3
# ('M80', 'M66', 'M15') 3
# ('M37', 'M5', 'M32') 5
# ('M45', 'M2', 'M15') 4
# ('M99', 'M71', 'M56') 3
# ('M69', 'M77', 'M6') 5
# ('M74', 'M87', 'M2') 3
# ('M76', 'M99', 'M15') 3
# ('M77', 'M2', 'M35') 3
# ('M26', 'M73', 'M16') 3
# ('M47', 'M90', 'M27') 3
# ('M93', 'M91', 'M87') 3
# ('M80', 'M78', 'M15') 3
# ('M45', 'M9', 'M15') 3
# ('M78', 'M3', 'M15') 6
# ('M62', 'M38', 'M93') 5
# ('M65', 'M73', 'M16') 5
# ('M23', 'M76', 'M71') 4
# ('M71', 'M8', 'M15') 3
# ('M62', 'M93', 'M73') 3
# ('M1', 'M11', 'M2') 3
# ('M22', 'M1', 'M46') 5
# ('M56', 'M14', 'M3') 3
# ('M56', 'M28', 'M15') 3
# ('M62', 'M71', 'M93') 3
# ('M51', 'M10', 'M87') 3
# ('M91', 'M78', 'M3') 3
# ('M23', 'M76', 'M99') 4
# ('M48', 'M53', 'M11') 3
# ('M37', 'M9', 'M73') 3
# ('M59', 'M99', 'M3') 3
# ('M65', 'M3', 'M73') 5
# ('M79', 'M77', 'M29') 5
# ('M99', 'M78', 'M3') 3
# ('M67', 'M18', 'M84') 5
# ('M37', 'M24', 'M72') 6
# ('M14', 'M22', 'M9') 5
# ('M99', 'M61', 'M25') 4
# ('M37', 'M70', 'M15') 4
# ('M37', 'M93', 'M27') 6
# ('M51', 'M10', 'M2') 3
# ('M80', 'M28', 'M9') 3
# ('M60', 'M50', 'M25') 3
# ('M62', 'M45', 'M73') 4
# ('M37', 'M98', 'M32') 3
# ('M78', 'M87', 'M2') 3
# ('M37', 'M27', 'M32') 5
# ('M79', 'M3', 'M73') 3
# ('M69', 'M63', 'M35') 3
# ('M62', 'M93', 'M15') 3
# ('M22', 'M9', 'M91') 5
# ('M37', 'M2', 'M15') 4
# ('M38', 'M18', 'M31') 3
# ('M8', 'M70', 'M15') 4
# ('M60', 'M93', 'M27') 3
# ('M91', 'M27', 'M15') 3
# ('M68', 'M92', 'M57') 3
# ('M74', 'M24', 'M78') 3
# ('M38', 'M93', 'M91') 3
# ('M61', 'M98', 'M48') 3
# ('M56', 'M64', 'M15') 3
# ('M44', 'M89', 'M84') 5
# ('M51', 'M74', 'M72') 5
# ('M22', 'M93', 'M9') 3
# ('M93', 'M12', 'M6') 3
# ('M45', 'M8', 'M15') 5
# ('M93', 'M91', 'M27') 3
# ('M68', 'M84', 'M66') 3
# ('M59', 'M56', 'M6') 3
# ('M32', 'M83', 'M2') 3
# ('M51', 'M47', 'M72') 5
# ('M98', 'M77', 'M35') 3
# ('M79', 'M77', 'M2') 5
# ('M60', 'M14', 'M48') 5
# ('M38', 'M67', 'M31') 3
# ('M84', 'M78', 'M73') 3
# ('M62', 'M45', 'M15') 3
# ('M61', 'M78', 'M15') 4
# ('M23', 'M14', 'M78') 3
# ('M77', 'M3', 'M15') 3
# ('M99', 'M70', 'M15') 3
# ('M94', 'M63', 'M15') 3
# ('M78', 'M6', 'M3') 3
# ('M84', 'M66', 'M92') 3
# ('M61', 'M21', 'M25') 4
# ('M12', 'M11', 'M6') 3
# ('M45', 'M63', 'M15') 4
# ('M62', 'M45', 'M38') 5
# ('M28', 'M9', 'M66') 4
# ('M72', 'M87', 'M35') 5
# ('M33', 'M89', 'M58') 4
# ('M44', 'M45', 'M89') 5
# ('M70', 'M3', 'M15') 3
# ('M77', 'M63', 'M35') 3
# ('M48', 'M84', 'M16') 3
# ('M80', 'M3', 'M15') 3
# ('M59', 'M80', 'M15') 3
# ('M59', 'M66', 'M15') 3
# ('M59', 'M80', 'M66') 3
# ('M68', 'M9', 'M17') 3
# ('M66', 'M78', 'M3') 4
# ('M24', 'M83', 'M2') 3
# ('M59', 'M78', 'M15') 5
# ('M37', 'M47', 'M70') 3
# ('M89', 'M11', 'M2') 3
# ('M90', 'M20', 'M73') 3
# ('M71', 'M20', 'M27') 3
# ('M9', 'M30', 'M35') 3
# ('M91', 'M17', 'M15') 3
# ('M80', 'M48', 'M84') 3
# ('M8', 'M2', 'M15') 3
# ('M78', 'M83', 'M2') 3
# ('M12', 'M77', 'M6') 5
# ('M80', 'M18', 'M25') 3
# ('M59', 'M80', 'M78') 3
# ('M45', 'M21', 'M73') 3
# ('M61', 'M17', 'M6') 5
# ('M37', 'M41', 'M47') 3
# ('M13', 'M84', 'M6') 4
# ('M45', 'M38', 'M32') 3
# ('M72', 'M53', 'M35') 5
# ('M45', 'M80', 'M84') 3
# ('M28', 'M27', 'M78') 3
# ('M61', 'M12', 'M6') 3
# ('M45', 'M38', 'M73') 4
# ('M22', 'M89', 'M2') 5
# ('M37', 'M72', 'M87') 3
# ('M38', 'M84', 'M31') 3
# ('M37', 'M95', 'M87') 3
# ('M99', 'M56', 'M3') 3
# ('M68', 'M66', 'M87') 5
# ('M23', 'M99', 'M15') 3
# ('M88', 'M66', 'M3') 4
# ('M80', 'M5', 'M84') 3
# ('M22', 'M2', 'M46') 6
# ('M14', 'M84', 'M53') 5
# ('M80', 'M9', 'M25') 4
# ('M77', 'M35', 'M29') 3
# ('M38', 'M91', 'M27') 3
# ('M10', 'M89', 'M2') 3
# ('M68', 'M93', 'M11') 3
# ('M14', 'M22', 'M27') 5
# ('M59', 'M3', 'M15') 7
# ('M68', 'M66', 'M92') 7
# ('M14', 'M91', 'M27') 5
# ('M80', 'M28', 'M25') 5
# ('M89', 'M1', 'M46') 5
# ('M65', 'M89', 'M73') 3
# ('M17', 'M12', 'M11') 3
# ('M59', 'M14', 'M78') 3
# ('M18', 'M32', 'M31') 3
# ('M45', 'M38', 'M15') 4
# ('M59', 'M91', 'M78') 3
# ('M93', 'M73', 'M29') 3
# ('M22', 'M98', 'M46') 3
# ('M22', 'M70', 'M15') 3
# ('M22', 'M93', 'M27') 3
# ('M66', 'M3', 'M16') 3
# ('M56', 'M68', 'M66') 3
# ('M41', 'M70', 'M15') 3
# ('M53', 'M87', 'M35') 5
# ('M13', 'M83', 'M6') 4
# ('M37', 'M24', 'M27') 3
# ('M76', 'M10', 'M1') 3
# ('M23', 'M78', 'M6') 3
# ('M33', 'M56', 'M64') 3
# ('M71', 'M93', 'M27') 3
# ('M74', 'M2', 'M15') 3
# ('M1', 'M63', 'M11') 3
# ('M23', 'M74', 'M55') 3
# ('M14', 'M93', 'M9') 4
# ('M1', 'M2', 'M46') 5
# ('M37', 'M24', 'M2') 3
# ('M50', 'M68', 'M66') 3
# ('M11', 'M6', 'M43') 5
# ('M60', 'M36', 'M84') 3
# ('M9', 'M17', 'M11') 4
# ('M78', 'M57', 'M3') 3
# ('M45', 'M87', 'M73') 3
# ('M74', 'M78', 'M2') 3
# ('M37', 'M72', 'M53') 3
# ('M22', 'M2', 'M73') 3
# ('M47', 'M70', 'M29') 3
# ('M33', 'M91', 'M64') 3
# ('M37', 'M72', 'M2') 3
# ('M45', 'M70', 'M2') 3
# ('M22', 'M89', 'M1') 5
# ('M79', 'M2', 'M73') 3
# ('M8', 'M63', 'M15') 4
# ('M80', 'M28', 'M30') 5
# ('M33', 'M18', 'M64') 3
# ('M98', 'M30', 'M2') 3
# ('M37', 'M7', 'M77') 3
# ('M55', 'M83', 'M2') 3
# ('M91', 'M78', 'M15') 4
# ('M38', 'M93', 'M73') 3
# ('M51', 'M56', 'M67') 3
# ('M8', 'M1', 'M2') 3
# ('M45', 'M87', 'M15') 3
# ('M23', 'M76', 'M40') 3
# ('M11', 'M2', 'M46') 3
# ('M59', 'M48', 'M84') 3
# ('M9', 'M3', 'M73') 6
# ('M5', 'M93', 'M27') 5
# ('M94', 'M9', 'M15') 3
# ('M44', 'M88', 'M70') 3
# ('M84', 'M83', 'M6') 4
# ('M71', 'M27', 'M32') 3
# ('M81', 'M43', 'M42') 3
# ('M74', 'M24', 'M87') 3
# ('M74', 'M3', 'M2') 3
# ('M79', 'M77', 'M35') 3
# ('M7', 'M6', 'M35') 3
# ('M14', 'M93', 'M27') 4
# ('M60', 'M48', 'M53') 6
# ('M74', 'M8', 'M15') 3
# ('M45', 'M41', 'M15') 3
# ('M69', 'M77', 'M35') 5
# ('M60', 'M53', 'M11') 3
# ('M22', 'M9', 'M15') 4
# ('M59', 'M99', 'M78') 3
# ('M37', 'M72', 'M27') 3
# ('M61', 'M6', 'M43') 5
# ('M45', 'M99', 'M84') 3
# ('M14', 'M22', 'M93') 3
# ('M45', 'M89', 'M84') 5
# ('M44', 'M84', 'M73') 5
# ('M80', 'M9', 'M30') 3
# ('M37', 'M65', 'M3') 4
# ('M74', 'M24', 'M2') 3
# ('M8', 'M17', 'M11') 3
# ('M93', 'M98', 'M32') 3
# ('M93', 'M27', 'M32') 6
# ('M61', 'M68', 'M98') 3
# ('M51', 'M61', 'M32') 3
# ('M23', 'M14', 'M9') 3
# ('M22', 'M27', 'M15') 3
# ('M24', 'M56', 'M3') 3
# ('M56', 'M91', 'M15') 3
# ('M45', 'M84', 'M73') 6
# ('M78', 'M6', 'M15') 3
# ('M98', 'M2', 'M46') 3
# ('M59', 'M99', 'M15') 3
# ('M9', 'M66', 'M3') 4
# ('M45', 'M84', 'M78') 3
# ('M37', 'M74', 'M10') 3
# ('M37', 'M65', 'M16') 3
# ('M99', 'M78', 'M15') 3
# ('M92', 'M87', 'M3') 5
# ('M47', 'M10', 'M72') 3
# ('M66', 'M73', 'M16') 3
# ('M37', 'M70', 'M29') 3
# ('M68', 'M84', 'M92') 4
# ('M62', 'M73', 'M29') 3
# ('M61', 'M11', 'M6') 5
# ('M60', 'M14', 'M84') 5
# ('M56', 'M78', 'M3') 5
# ('M5', 'M27', 'M32') 5
# ('M37', 'M7', 'M93') 3
# ('M74', 'M95', 'M15') 3
# ('M62', 'M93', 'M29') 5
# ('M37', 'M5', 'M27') 5
# ('M14', 'M27', 'M32') 3
# ('M59', 'M56', 'M64') 3
# ('M47', 'M34', 'M72') 3
# ('M9', 'M66', 'M16') 3
# ('M45', 'M84', 'M15') 4
# ('M60', 'M56', 'M50') 5
# ('M68', 'M89', 'M46') 3
# ('M44', 'M89', 'M73') 5
# ('M59', 'M80', 'M9') 3
# ('M98', 'M27', 'M32') 3
# ('M80', 'M66', 'M25') 5
# ('M98', 'M63', 'M2') 3
# ('M71', 'M88', 'M27') 3
# ('M61', 'M21', 'M96') 3
# ('M37', 'M70', 'M2') 4
# ('M62', 'M45', 'M29') 5
# ('M9', 'M27', 'M15') 3
# ('M10', 'M68', 'M46') 3
# ('M37', 'M10', 'M3') 3
# ('M18', 'M32', 'M42') 3
# ('M99', 'M71', 'M15') 5
# ('M99', 'M56', 'M15') 3
# ('M89', 'M2', 'M46') 5
# ('M14', 'M27', 'M15') 3
# ('M69', 'M12', 'M6') 5
# ('M99', 'M18', 'M32') 3
# ('M10', 'M72', 'M87') 3
# ('M67', 'M18', 'M32') 5
# ('M70', 'M3', 'M29') 3
# ('M71', 'M56', 'M6') 3
# ('M10', 'M95', 'M87') 3
# ('M80', 'M25', 'M78') 3
# ('M22', 'M1', 'M2') 5
# ('M59', 'M48', 'M16') 3
# ('M56', 'M66', 'M92') 3
# ('M28', 'M66', 'M3') 3
# ('M79', 'M9', 'M3') 3
# ('M37', 'M10', 'M83') 5
# ('M37', 'M38', 'M72') 3
# ('M99', 'M56', 'M78') 3
# ('M66', 'M3', 'M73') 4
# ('M56', 'M22', 'M91') 4
# ('M28', 'M78', 'M3') 4
# ('M71', 'M21', 'M6') 3
# ('M24', 'M72', 'M27') 3
# ('M12', 'M77', 'M35') 5
# ('M44', 'M45', 'M84') 6
# ('M80', 'M84', 'M6') 3
# ('M93', 'M9', 'M91') 3
# ('M80', 'M66', 'M30') 5
# ('M17', 'M11', 'M43') 5
# ('M84', 'M53', 'M30') 3
# ('M44', 'M45', 'M80') 3
# ('M5', 'M93', 'M12') 3
# ('M12', 'M6', 'M46') 3
# ('M50', 'M27', 'M55') 4
# ('M56', 'M68', 'M92') 6
# ('M66', 'M3', 'M15') 4
# ('M30', 'M3', 'M15') 3
# ('M89', 'M2', 'M73') 3
# ('M10', 'M72', 'M53') 3
# ('M74', 'M66', 'M3') 3
# ('M74', 'M70', 'M15') 3
# ('M50', 'M68', 'M92') 6
# ('M23', 'M59', 'M76') 3
# ('M60', 'M84', 'M78') 3
# ('M37', 'M17', 'M32') 3
# ('M37', 'M5', 'M93') 5
# ('M38', 'M32', 'M31') 3
# ('M68', 'M78', 'M92') 3
# ('M37', 'M3', 'M16') 3
# ('M45', 'M38', 'M29') 5
# ('M28', 'M9', 'M25') 3
# ('M9', 'M3', 'M16') 5
# ('M10', 'M72', 'M2') 3
# ('M51', 'M95', 'M87') 3
# ('M56', 'M21', 'M6') 3
# ('M60', 'M50', 'M84') 3
# ('M37', 'M65', 'M73') 3
# ('M67', 'M84', 'M32') 5
# ('M56', 'M14', 'M9') 3
# ('M37', 'M98', 'M17') 3
# ('M38', 'M72', 'M63') 3
# ('M23', 'M75', 'M55') 3
# ('M36', 'M48', 'M84') 3
# ('M60', 'M14', 'M11') 3
# ('M38', 'M73', 'M29') 3
# ('M14', 'M7', 'M27') 3
# ('M77', 'M73', 'M29') 3
# ('M72', 'M63', 'M15') 3
# ('M9', 'M66', 'M73') 3
# ('M69', 'M12', 'M77') 5
# ('M62', 'M61', 'M93') 3
# ('M10', 'M61', 'M82') 3
# ('M59', 'M28', 'M96') 3
# ('M80', 'M40', 'M3') 3
# ('M74', 'M61', 'M8') 3
# ('M47', 'M3', 'M29') 3
# ('M22', 'M70', 'M2') 3
# ('M22', 'M91', 'M15') 4
# ('M18', 'M96', 'M32') 3
# ('M60', 'M68', 'M92') 5
# ('M62', 'M45', 'M93') 5
# ('M60', 'M56', 'M68') 5
# ('M18', 'M55', 'M32') 3
# ('M49', 'M14', 'M72') 3
# ('M62', 'M28', 'M15') 4
# ('M45', 'M8', 'M70') 3
# ('M14', 'M9', 'M91') 5
# ('M62', 'M28', 'M66') 3
# ('M28', 'M9', 'M30') 4
# ('M24', 'M10', 'M83') 5
# ('M45', 'M71', 'M15') 4
# ('M7', 'M77', 'M6') 3
# ('M62', 'M93', 'M12') 3
# ('M62', 'M28', 'M95') 3
# ('M68', 'M11', 'M2') 3
# ('M98', 'M1', 'M2') 3
# ('M14', 'M48', 'M53') 5
# ('M84', 'M32', 'M31') 3
# ('M74', 'M63', 'M87') 3
# ('M81', 'M2', 'M29') 3
# ('M89', 'M1', 'M2') 5
# ('M99', 'M61', 'M21') 4
# ('M37', 'M24', 'M10') 5
# ('M10', 'M94', 'M82') 3
# ('M56', 'M78', 'M15') 5
# ('M48', 'M84', 'M53') 5
# ('M62', 'M63', 'M29') 3
# ('M37', 'M41', 'M72') 3
# ('M61', 'M43', 'M15') 3
# ('M56', 'M21', 'M27') 3
# ('M79', 'M2', 'M29') 6
# ('M76', 'M99', 'M71') 4
# ('M22', 'M98', 'M2') 3
# ('M38', 'M93', 'M29') 5
# ('M68', 'M92', 'M3') 5
# ('M91', 'M3', 'M15') 4
# ('M23', 'M76', 'M15') 3
# ('M66', 'M78', 'M87') 3
# ('M10', 'M98', 'M2') 3
# ('M79', 'M9', 'M73') 4
# ('M45', 'M38', 'M61') 3
# ('M45', 'M72', 'M84') 3
# ('M7', 'M12', 'M6') 3
# ('M22', 'M9', 'M27') 5
# ('M37', 'M73', 'M16') 3
# ('M38', 'M93', 'M27') 3
# ('M66', 'M78', 'M92') 3
# ('M84', 'M27', 'M83') 3
# ('M99', 'M71', 'M6') 3
# ('M99', 'M21', 'M25') 4
# ('M23', 'M50', 'M55') 4
# ('M76', 'M71', 'M56') 3
# ('M99', 'M56', 'M6') 3
# ('M60', 'M56', 'M92') 5
# ('M37', 'M10', 'M38') 4
# ('M38', 'M18', 'M84') 5
# ('M59', 'M80', 'M48') 3
# ('M99', 'M61', 'M83') 3
# ('M38', 'M22', 'M93') 3
# ('M63', 'M53', 'M87') 5
# ('M14', 'M7', 'M93') 3
# ('M45', 'M38', 'M93') 5
# ('M59', 'M47', 'M27') 3
# ('M37', 'M3', 'M73') 3
# ('M28', 'M66', 'M15') 3
# ('M69', 'M7', 'M6') 3
# ('M23', 'M24', 'M31') 3
# ('M70', 'M2', 'M15') 6
# ('M45', 'M99', 'M63') 3
# ('M38', 'M67', 'M84') 5
# ('M74', 'M72', 'M87') 3
# ('M17', 'M12', 'M6') 3
# ('M10', 'M38', 'M72') 3
# ('M78', 'M87', 'M3') 3
# ('M28', 'M78', 'M15') 3
# ('M45', 'M89', 'M73') 5
# ('M8', 'M11', 'M15') 3
# ('M98', 'M2', 'M29') 5
# ('M9', 'M91', 'M15') 3
# ('M66', 'M92', 'M3') 5
# ('M38', 'M67', 'M18') 5
# ('M17', 'M11', 'M15') 3
# ('M93', 'M98', 'M27') 3
# ('M86', 'M95', 'M15') 4
# ('M28', 'M66', 'M78') 4
# ('M94', 'M9', 'M17') 3
# ('M56', 'M3', 'M15') 5
# ('M62', 'M38', 'M73') 3
# ('M63', 'M87', 'M2') 3
# ('M45', 'M73', 'M15') 3
# ('M66', 'M57', 'M3') 4
# ('M68', 'M17', 'M11') 3
# ('M23', 'M99', 'M71') 4
# ('M69', 'M12', 'M35') 5
# ('M9', 'M17', 'M6') 3
# ('M13', 'M70', 'M15') 3
# ('M51', 'M71', 'M21') 3
# ('M67', 'M18', 'M31') 3
# ('M74', 'M61', 'M98') 3
# ('M28', 'M3', 'M15') 3
# ('M45', 'M41', 'M8') 3
# ('M11', 'M6', 'M2') 3
# ('M65', 'M9', 'M16') 5
# ('M14', 'M9', 'M15') 3
# ('M45', 'M93', 'M73') 3
# ('M68', 'M22', 'M8') 3
# ('M80', 'M27', 'M78') 3
# ('M37', 'M65', 'M9') 3
# ('M99', 'M3', 'M15') 3
# ('M9', 'M17', 'M2') 4
# ('M18', 'M84', 'M32') 5
# ('M44', 'M45', 'M73') 5
# ('M6', 'M3', 'M15') 3
# ('M7', 'M12', 'M77') 3
# ('M18', 'M98', 'M77') 3
# ('M3', 'M73', 'M16') 5
# ('M65', 'M9', 'M3') 5
# ('M74', 'M70', 'M2') 3
# ('M14', 'M28', 'M78') 3
# ('M10', 'M68', 'M92') 3
# ('M74', 'M8', 'M70') 3
# ('M89', 'M70', 'M2') 3
# ('M72', 'M63', 'M87') 5
# ('M37', 'M63', 'M35') 3
# ('M74', 'M95', 'M8') 4
# ('M66', 'M78', 'M57') 3
# ('M60', 'M84', 'M53') 5
# ('M66', 'M25', 'M30') 5
# ('M41', 'M84', 'M87') 3
# ('M1', 'M63', 'M2') 3
# ('M69', 'M7', 'M77') 3
# ('M37', 'M10', 'M72') 7
# ('M50', 'M66', 'M92') 3
# ('M59', 'M56', 'M3') 5
# ('M59', 'M76', 'M78') 3
# ('M80', 'M9', 'M3') 3
# ('M14', 'M22', 'M91') 5
# ('M49', 'M18', 'M30') 3
# ('M93', 'M27', 'M12') 3
# ('M61', 'M87', 'M3') 3
# ('M59', 'M27', 'M78') 3
# ('M60', 'M48', 'M84') 6
# ('M98', 'M17', 'M32') 3
# ('M37', 'M24', 'M83') 5
# ('M41', 'M47', 'M72') 4
# ('M17', 'M6', 'M43') 5
# ('M51', 'M74', 'M47') 5
# ('M67', 'M84', 'M31') 3
# ('M71', 'M38', 'M27') 3
# ('M38', 'M72', 'M53') 3
# ('M35', 'M73', 'M29') 4
# ('M80', 'M9', 'M16') 3
# ('M22', 'M93', 'M91') 3
# ('M28', 'M91', 'M57') 3
# ('M13', 'M84', 'M83') 4
# ('M80', 'M25', 'M30') 5
# ('M60', 'M84', 'M27') 3
# ('M23', 'M8', 'M55') 3
# ('M33', 'M56', 'M78') 3
# ('M14', 'M90', 'M1') 3
# ('M72', 'M63', 'M53') 5
# ('M7', 'M12', 'M35') 3
# ('M61', 'M17', 'M11') 5
# ('M37', 'M93', 'M32') 5
# ('M41', 'M17', 'M6') 3
# ('M10', 'M56', 'M92') 3
# ('M7', 'M77', 'M35') 4
# ('M61', 'M13', 'M68') 3
# ('M51', 'M21', 'M92') 3
# ('M68', 'M66', 'M3') 5
# ('M69', 'M7', 'M12') 3
# ('M89', 'M8', 'M2') 3
# ('M99', 'M18', 'M61') 3
# ('M74', 'M10', 'M72') 3
# ('M74', 'M98', 'M2') 3
# ('M22', 'M91', 'M27') 5
# ('M37', 'M10', 'M87') 4
# Runtime: 2835.1658136844635 seconds

# %%
start_time = time.time()
df = pd.read_csv('transactionlarge.csv', header=None)

data_set = []
for index, row in df.iterrows():
    data_row = []
    for value in row.values:
        if str(value) != 'nan':
            data_row.append(value)
    data_set.append(data_row)

te = TransactionEncoder()
te_array = te.fit(data_set).transform(data_set)

data_frame = pd.DataFrame(te_array, columns=te.columns_)
apriori_frequent_item_sets(data_frame, 4, 3)
print(f'Runtime: {time.time() - start_time} seconds')
# Out:
# ('M49') 20
# ('M23') 23
# ('M37') 34
# ('M44') 21
# ('M59') 27
# ('M69') 23
# ('M62') 27
# ('M33') 20
# ('M45') 34
# ('M51') 31
# ('M79') 26
# ('M80') 27
# ('M76') 24
# ('M60') 28
# ('M65') 23
# ('M74') 32
# ('M24') 26
# ('M41') 22
# ('M47') 21
# ('M19') 17
# ('M10') 35
# ('M99') 24
# ('M54') 23
# ('M71') 23
# ('M38') 31
# ('M56') 36
# ('M67') 24
# ('M14') 30
# ('M88') 21
# ('M94') 21
# ('M50') 29
# ('M28') 30
# ('M18') 28
# ('M5') 29
# ('M61') 36
# ('M36') 16
# ('M52') 23
# ('M13') 18
# ('M68') 29
# ('M86') 20
# ('M95') 25
# ('M90') 22
# ('M21') 22
# ('M85') 8
# ('M7') 18
# ('M75') 17
# ('M22') 27
# ('M34') 18
# ('M93') 32
# ('M9') 30
# ('M89') 26
# ('M8') 30
# ('M98') 31
# ('M72') 31
# ('M91') 34
# ('M97') 19
# ('M20') 22
# ('M48') 21
# ('M84') 39
# ('M66') 30
# ('M25') 26
# ('M17') 27
# ('M82') 19
# ('M27') 38
# ('M1') 28
# ('M64') 20
# ('M81') 18
# ('M96') 15
# ('M78') 31
# ('M12') 23
# ('M92') 31
# ('M40') 19
# ('M55') 32
# ('M4') 19
# ('M77') 31
# ('M63') 29
# ('M32') 32
# ('M57') 25
# ('M53') 23
# ('M11') 28
# ('M83') 31
# ('M6') 36
# ('M87') 29
# ('M43') 22
# ('M70') 24
# ('M31') 23
# ('M42') 19
# ('M58') 17
# ('M3') 35
# ('M30') 31
# ('M2') 41
# ('M46') 26
# ('M26') 14
# ('M35') 30
# ('M73') 33
# ('M15') 40
# ('M16') 19
# ('M29') 32
# ('M23', 'M15') 4
# ('M61', 'M17') 7
# ('M14', 'M15') 6
# ('M13', 'M15') 4
# ('M32', 'M42') 7
# ('M62', 'M25') 4
# ('M77', 'M3') 5
# ('M65', 'M56') 4
# ('M79', 'M3') 4
# ('M51', 'M84') 5
# ('M9', 'M91') 8
# ('M14', 'M20') 4
# ('M45', 'M87') 4
# ('M99', 'M56') 4
# ('M67', 'M6') 6
# ('M66', 'M27') 5
# ('M43', 'M15') 4
# ('M22', 'M70') 4
# ('M66', 'M78') 7
# ('M62', 'M8') 5
# ('M24', 'M15') 5
# ('M49', 'M24') 4
# ('M84', 'M32') 5
# ('M30', 'M29') 4
# ('M56', 'M92') 7
# ('M95', 'M30') 5
# ('M89', 'M15') 4
# ('M69', 'M93') 4
# ('M59', 'M14') 4
# ('M57', 'M15') 5
# ('M66', 'M25') 6
# ('M60', 'M73') 4
# ('M74', 'M3') 4
# ('M80', 'M73') 4
# ('M80', 'M5') 4
# ('M25', 'M32') 5
# ('M60', 'M29') 5
# ('M65', 'M61') 4
# ('M52', 'M93') 5
# ('M95', 'M55') 4
# ('M84', 'M27') 6
# ('M69', 'M62') 5
# ('M38', 'M75') 4
# ('M9', 'M72') 4
# ('M79', 'M89') 4
# ('M88', 'M66') 6
# ('M51', 'M74') 6
# ('M8', 'M70') 7
# ('M45', 'M63') 6
# ('M25', 'M27') 4
# ('M84', 'M78') 7
# ('M60', 'M65') 5
# ('M51', 'M10') 5
# ('M72', 'M35') 5
# ('M65', 'M66') 4
# ('M53', 'M87') 6
# ('M38', 'M73') 5
# ('M38', 'M5') 5
# ('M84', 'M25') 5
# ('M17', 'M11') 9
# ('M93', 'M66') 4
# ('M38', 'M29') 8
# ('M28', 'M84') 5
# ('M27', 'M58') 4
# ('M56', 'M28') 4
# ('M93', 'M17') 5
# ('M67', 'M18') 5
# ('M91', 'M29') 5
# ('M78', 'M6') 5
# ('M74', 'M89') 4
# ('M24', 'M38') 4
# ('M76', 'M55') 4
# ('M56', 'M91') 6
# ('M50', 'M93') 4
# ('M13', 'M70') 6
# ('M10', 'M98') 4
# ('M62', 'M73') 4
# ('M62', 'M5') 5
# ('M56', 'M67') 4
# ('M37', 'M41') 4
# ('M78', 'M30') 4
# ('M99', 'M78') 4
# ('M22', 'M84') 4
# ('M62', 'M29') 7
# ('M62', 'M77') 4
# ('M7', 'M27') 4
# ('M22', 'M2') 7
# ('M49', 'M8') 4
# ('M59', 'M96') 4
# ('M45', 'M74') 4
# ('M80', 'M15') 5
# ('M68', 'M84') 5
# ('M7', 'M78') 5
# ('M73', 'M16') 6
# ('M44', 'M45') 7
# ('M41', 'M2') 4
# ('M59', 'M16') 5
# ('M78', 'M16') 4
# ('M66', 'M73') 4
# ('M57', 'M70') 5
# ('M74', 'M87') 6
# ('M41', 'M6') 4
# ('M37', 'M3') 7
# ('M40', 'M15') 5
# ('M56', 'M3') 9
# ('M77', 'M63') 6
# ('M66', 'M77') 4
# ('M3', 'M2') 8
# ('M56', 'M14') 5
# ('M38', 'M15') 4
# ('M6', 'M73') 6
# ('M41', 'M4') 4
# ('M61', 'M98') 8
# ('M8', 'M2') 5
# ('M86', 'M32') 4
# ('M28', 'M61') 5
# ('M79', 'M82') 4
# ('M98', 'M57') 5
# ('M9', 'M16') 6
# ('M91', 'M1') 4
# ('M91', 'M15') 8
# ('M40', 'M3') 4
# ('M84', 'M73') 7
# ('M64', 'M16') 4
# ('M59', 'M6') 4
# ('M62', 'M15') 6
# ('M45', 'M94') 4
# ('M28', 'M66') 9
# ('M25', 'M73') 6
# ('M13', 'M84') 4
# ('M11', 'M2') 11
# ('M66', 'M83') 4
# ('M11', 'M6') 10
# ('M47', 'M92') 4
# ('M10', 'M72') 8
# ('M14', 'M48') 5
# ('M59', 'M30') 4
# ('M61', 'M93') 4
# ('M14', 'M2') 5
# ('M94', 'M32') 4
# ('M61', 'M57') 4
# ('M45', 'M78') 4
# ('M67', 'M52') 5
# ('M10', 'M71') 4
# ('M10', 'M38') 8
# ('M74', 'M30') 5
# ('M94', 'M27') 6
# ('M74', 'M55') 7
# ('M71', 'M84') 5
# ('M9', 'M30') 6
# ('M63', 'M6') 4
# ('M66', 'M15') 7
# ('M84', 'M83') 9
# ('M5', 'M84') 4
# ('M5', 'M12') 5
# ('M28', 'M9') 6
# ('M24', 'M2') 7
# ('M9', 'M55') 5
# ('M25', 'M83') 4
# ('M63', 'M30') 4
# ('M89', 'M2') 7
# ('M93', 'M92') 4
# ('M37', 'M87') 6
# ('M62', 'M81') 4
# ('M64', 'M55') 4
# ('M70', 'M15') 9
# ('M76', 'M8') 5
# ('M72', 'M91') 5
# ('M47', 'M91') 4
# ('M84', 'M64') 4
# ('M7', 'M77') 6
# ('M93', 'M98') 6
# ('M51', 'M21') 5
# ('M90', 'M27') 8
# ('M24', 'M56') 5
# ('M38', 'M70') 5
# ('M22', 'M9') 8
# ('M18', 'M98') 4
# ('M84', 'M15') 5
# ('M81', 'M42') 4
# ('M8', 'M17') 4
# ('M23', 'M24') 4
# ('M75', 'M6') 4
# ('M17', 'M63') 4
# ('M12', 'M35') 6
# ('M72', 'M1') 4
# ('M68', 'M9') 4
# ('M63', 'M15') 8
# ('M70', 'M3') 6
# ('M44', 'M8') 4
# ('M14', 'M53') 6
# ('M79', 'M78') 4
# ('M37', 'M63') 4
# ('M18', 'M93') 4
# ('M47', 'M72') 10
# ('M93', 'M91') 6
# ('M91', 'M87') 4
# ('M68', 'M22') 6
# ('M14', 'M17') 4
# ('M83', 'M6') 5
# ('M34', 'M72') 4
# ('M37', 'M12') 4
# ('M59', 'M35') 4
# ('M50', 'M6') 4
# ('M72', 'M3') 5
# ('M45', 'M73') 11
# ('M45', 'M5') 4
# ('M56', 'M30') 4
# ('M23', 'M78') 4
# ('M60', 'M84') 9
# ('M9', 'M32') 5
# ('M45', 'M29') 7
# ('M79', 'M68') 4
# ('M51', 'M93') 4
# ('M45', 'M21') 4
# ('M60', 'M48') 7
# ('M56', 'M55') 6
# ('M59', 'M47') 4
# ('M80', 'M48') 5
# ('M88', 'M3') 6
# ('M10', 'M95') 4
# ('M74', 'M78') 4
# ('M9', 'M35') 5
# ('M9', 'M27') 6
# ('M23', 'M9') 4
# ('M74', 'M47') 7
# ('M69', 'M53') 4
# ('M74', 'M88') 4
# ('M63', 'M35') 8
# ('M10', 'M2') 6
# ('M38', 'M84') 6
# ('M61', 'M96') 4
# ('M93', 'M72') 4
# ('M60', 'M56') 6
# ('M44', 'M73') 5
# ('M80', 'M56') 4
# ('M9', 'M25') 5
# ('M99', 'M71') 7
# ('M38', 'M2') 4
# ('M74', 'M68') 5
# ('M37', 'M74') 5
# ('M14', 'M22') 6
# ('M71', 'M88') 4
# ('M37', 'M10') 8
# ('M45', 'M97') 5
# ('M25', 'M70') 4
# ('M74', 'M8') 7
# ('M24', 'M31') 4
# ('M22', 'M92') 4
# ('M12', 'M46') 4
# ('M62', 'M84') 5
# ('M62', 'M12') 4
# ('M90', 'M73') 5
# ('M38', 'M56') 4
# ('M33', 'M18') 4
# ('M51', 'M71') 5
# ('M86', 'M15') 7
# ('M95', 'M3') 4
# ('M22', 'M98') 5
# ('M45', 'M64') 4
# ('M98', 'M30') 5
# ('M37', 'M24') 10
# ('M90', 'M77') 4
# ('M45', 'M76') 4
# ('M45', 'M15') 12
# ('M50', 'M66') 4
# ('M17', 'M27') 5
# ('M27', 'M6') 6
# ('M76', 'M1') 4
# ('M77', 'M73') 6
# ('M28', 'M57') 5
# ('M79', 'M73') 6
# ('M61', 'M2') 5
# ('M37', 'M32') 7
# ('M23', 'M75') 6
# ('M61', 'M6') 7
# ('M72', 'M87') 8
# ('M77', 'M29') 7
# ('M79', 'M29') 7
# ('M62', 'M56') 4
# ('M12', 'M77') 6
# ('M79', 'M77') 6
# ('M10', 'M61') 7
# ('M60', 'M66') 4
# ('M52', 'M22') 4
# ('M60', 'M53') 7
# ('M37', 'M27') 8
# ('M80', 'M66') 9
# ('M56', 'M94') 4
# ('M94', 'M15') 6
# ('M56', 'M27') 5
# ('M23', 'M50') 5
# ('M80', 'M53') 5
# ('M27', 'M55') 5
# ('M22', 'M93') 6
# ('M73', 'M29') 7
# ('M38', 'M61') 4
# ('M60', 'M17') 4
# ('M62', 'M74') 4
# ('M24', 'M58') 5
# ('M56', 'M78') 9
# ('M31', 'M2') 5
# ('M44', 'M15') 4
# ('M87', 'M2') 5
# ('M1', 'M55') 7
# ('M37', 'M25') 4
# ('M56', 'M25') 5
# ('M68', 'M93') 5
# ('M45', 'M71') 4
# ('M38', 'M53') 4
# ('M77', 'M83') 4
# ('M79', 'M83') 4
# ('M65', 'M16') 6
# ('M78', 'M3') 8
# ('M72', 'M63') 7
# ('M9', 'M73') 7
# ('M56', 'M68') 8
# ('M14', 'M98') 4
# ('M10', 'M35') 4
# ('M34', 'M30') 5
# ('M37', 'M51') 6
# ('M54', 'M2') 4
# ('M71', 'M21') 5
# ('M6', 'M43') 5
# ('M56', 'M8') 4
# ('M17', 'M43') 5
# ('M90', 'M20') 6
# ('M77', 'M15') 5
# ('M95', 'M87') 6
# ('M23', 'M59') 4
# ('M91', 'M78') 6
# ('M65', 'M6') 4
# ('M6', 'M46') 4
# ('M45', 'M70') 6
# ('M38', 'M9') 4
# ('M38', 'M31') 5
# ('M98', 'M35') 4
# ('M68', 'M72') 4
# ('M37', 'M7') 6
# ('M14', 'M28') 4
# ('M33', 'M58') 5
# ('M14', 'M93') 5
# ('M99', 'M6') 4
# ('M59', 'M64') 5
# ('M23', 'M76') 5
# ('M14', 'M91') 7
# ('M93', 'M82') 4
# ('M5', 'M98') 4
# ('M32', 'M83') 7
# ('M44', 'M89') 5
# ('M18', 'M30') 6
# ('M91', 'M27') 7
# ('M56', 'M46') 5
# ('M9', 'M11') 4
# ('M74', 'M15') 5
# ('M61', 'M35') 5
# ('M51', 'M2') 5
# ('M27', 'M1') 4
# ('M17', 'M29') 4
# ('M18', 'M55') 4
# ('M67', 'M12') 4
# ('M63', 'M11') 4
# ('M71', 'M93') 5
# ('M9', 'M1') 4
# ('M59', 'M3') 8
# ('M37', 'M73') 5
# ('M37', 'M5') 5
# ('M71', 'M15') 8
# ('M56', 'M5') 4
# ('M24', 'M91') 4
# ('M32', 'M15') 5
# ('M62', 'M22') 4
# ('M5', 'M93') 8
# ('M28', 'M96') 4
# ('M37', 'M29') 5
# ('M51', 'M56') 5
# ('M60', 'M50') 7
# ('M84', 'M53') 7
# ('M64', 'M15') 4
# ('M78', 'M87') 5
# ('M37', 'M77') 4
# ('M56', 'M21') 6
# ('M14', 'M72') 4
# ('M87', 'M35') 8
# ('M50', 'M92') 6
# ('M23', 'M71') 4
# ('M49', 'M66') 4
# ('M72', 'M32') 4
# ('M37', 'M65') 4
# ('M28', 'M16') 4
# ('M9', 'M3') 7
# ('M99', 'M61') 8
# ('M18', 'M61') 6
# ('M47', 'M27') 4
# ('M60', 'M92') 6
# ('M99', 'M18') 5
# ('M64', 'M3') 4
# ('M45', 'M84') 9
# ('M77', 'M70') 4
# ('M36', 'M84') 5
# ('M28', 'M95') 4
# ('M37', 'M83') 7
# ('M24', 'M72') 7
# ('M45', 'M2') 6
# ('M21', 'M6') 6
# ('M84', 'M31') 5
# ('M10', 'M92') 5
# ('M49', 'M60') 5
# ('M88', 'M27') 5
# ('M78', 'M63') 4
# ('M6', 'M15') 4
# ('M71', 'M38') 4
# ('M17', 'M15') 6
# ('M99', 'M17') 4
# ('M93', 'M32') 8
# ('M28', 'M6') 4
# ('M96', 'M32') 4
# ('M33', 'M91') 4
# ('M44', 'M63') 4
# ('M18', 'M36') 4
# ('M69', 'M14') 4
# ('M51', 'M66') 4
# ('M56', 'M64') 6
# ('M28', 'M30') 7
# ('M44', 'M84') 7
# ('M74', 'M70') 5
# ('M37', 'M15') 4
# ('M3', 'M16') 5
# ('M56', 'M15') 7
# ('M80', 'M28') 8
# ('M51', 'M17') 4
# ('M60', 'M93') 4
# ('M67', 'M32') 8
# ('M28', 'M55') 5
# ('M80', 'M91') 4
# ('M68', 'M2') 6
# ('M41', 'M63') 5
# ('M76', 'M10') 4
# ('M61', 'M92') 5
# ('M45', 'M80') 4
# ('M67', 'M78') 4
# ('M95', 'M27') 4
# ('M12', 'M63') 5
# ('M7', 'M9') 4
# ('M38', 'M93') 7
# ('M45', 'M61') 6
# ('M48', 'M84') 8
# ('M51', 'M31') 4
# ('M55', 'M63') 4
# ('M8', 'M6') 4
# ('M92', 'M6') 4
# ('M3', 'M30') 4
# ('M63', 'M87') 8
# ('M70', 'M29') 5
# ('M77', 'M2') 7
# ('M60', 'M72') 4
# ('M62', 'M93') 8
# ('M91', 'M20') 4
# ('M27', 'M83') 8
# ('M46', 'M35') 5
# ('M60', 'M14') 7
# ('M45', 'M17') 4
# ('M8', 'M55') 5
# ('M49', 'M50') 4
# ('M98', 'M1') 5
# ('M74', 'M63') 4
# ('M23', 'M40') 4
# ('M72', 'M73') 5
# ('M25', 'M29') 4
# ('M37', 'M79') 4
# ('M10', 'M3') 7
# ('M23', 'M6') 6
# ('M27', 'M11') 4
# ('M25', 'M77') 4
# ('M13', 'M2') 5
# ('M14', 'M6') 4
# ('M72', 'M29') 5
# ('M13', 'M6') 5
# ('M78', 'M32') 4
# ('M74', 'M84') 5
# ('M95', 'M8') 4
# ('M33', 'M89') 4
# ('M61', 'M91') 5
# ('M38', 'M72') 6
# ('M61', 'M11') 5
# ('M76', 'M78') 4
# ('M93', 'M46') 5
# ('M1', 'M11') 4
# ('M88', 'M73') 4
# ('M37', 'M70') 7
# ('M81', 'M73') 5
# ('M9', 'M84') 4
# ('M45', 'M9') 4
# ('M66', 'M57') 5
# ('M2', 'M46') 8
# ('M61', 'M1') 5
# ('M68', 'M66') 7
# ('M71', 'M6') 6
# ('M76', 'M68') 4
# ('M51', 'M99') 4
# ('M89', 'M6') 4
# ('M68', 'M17') 5
# ('M72', 'M83') 5
# ('M57', 'M6') 4
# ('M59', 'M74') 5
# ('M2', 'M73') 7
# ('M94', 'M9') 4
# ('M62', 'M38') 5
# ('M10', 'M89') 4
# ('M69', 'M6') 7
# ('M27', 'M3') 4
# ('M65', 'M54') 4
# ('M61', 'M3') 6
# ('M2', 'M29') 7
# ('M44', 'M88') 4
# ('M84', 'M57') 6
# ('M71', 'M56') 5
# ('M48', 'M53') 7
# ('M18', 'M34') 4
# ('M74', 'M10') 5
# ('M55', 'M32') 4
# ('M51', 'M92') 5
# ('M72', 'M15') 5
# ('M17', 'M12') 4
# ('M93', 'M42') 4
# ('M31', 'M3') 4
# ('M41', 'M47') 4
# ('M87', 'M3') 8
# ('M74', 'M24') 5
# ('M80', 'M16') 6
# ('M90', 'M31') 4
# ('M10', 'M87') 6
# ('M82', 'M77') 4
# ('M47', 'M3') 5
# ('M93', 'M11') 4
# ('M18', 'M91') 4
# ('M59', 'M27') 5
# ('M61', 'M89') 4
# ('M45', 'M99') 4
# ('M99', 'M67') 4
# ('M79', 'M9') 4
# ('M5', 'M61') 4
# ('M37', 'M2') 7
# ('M7', 'M93') 4
# ('M59', 'M78') 9
# ('M41', 'M8') 5
# ('M96', 'M15') 4
# ('M18', 'M1') 4
# ('M95', 'M83') 4
# ('M51', 'M91') 4
# ('M95', 'M97') 5
# ('M2', 'M15') 8
# ('M80', 'M6') 4
# ('M50', 'M55') 6
# ('M23', 'M31') 7
# ('M79', 'M22') 5
# ('M51', 'M41') 5
# ('M78', 'M73') 4
# ('M60', 'M30') 5
# ('M65', 'M3') 8
# ('M67', 'M15') 4
# ('M80', 'M30') 5
# ('M10', 'M63') 4
# ('M9', 'M78') 4
# ('M99', 'M3') 4
# ('M61', 'M87') 4
# ('M95', 'M15') 6
# ('M59', 'M51') 4
# ('M10', 'M82') 4
# ('M24', 'M27') 5
# ('M30', 'M2') 4
# ('M44', 'M21') 4
# ('M41', 'M46') 6
# ('M92', 'M43') 4
# ('M66', 'M96') 4
# ('M69', 'M35') 8
# ('M62', 'M95') 4
# ('M47', 'M70') 5
# ('M98', 'M63') 5
# ('M74', 'M22') 4
# ('M51', 'M72') 6
# ('M38', 'M55') 4
# ('M37', 'M61') 4
# ('M66', 'M16') 4
# ('M17', 'M53') 4
# ('M62', 'M6') 4
# ('M45', 'M93') 5
# ('M41', 'M5') 4
# ('M45', 'M57') 5
# ('M78', 'M83') 5
# ('M11', 'M43') 5
# ('M68', 'M92') 13
# ('M41', 'M29') 4
# ('M47', 'M87') 4
# ('M3', 'M73') 7
# ('M52', 'M25') 4
# ('M37', 'M66') 4
# ('M27', 'M12') 4
# ('M28', 'M91') 4
# ('M28', 'M11') 4
# ('M3', 'M29') 5
# ('M59', 'M75') 5
# ('M1', 'M63') 5
# ('M55', 'M29') 4
# ('M25', 'M96') 4
# ('M11', 'M46') 5
# ('M61', 'M82') 4
# ('M37', 'M17') 5
# ('M90', 'M98') 6
# ('M23', 'M99') 4
# ('M66', 'M40') 4
# ('M78', 'M15') 8
# ('M66', 'M6') 4
# ('M50', 'M27') 7
# ('M22', 'M91') 8
# ('M5', 'M52') 4
# ('M68', 'M42') 4
# ('M30', 'M35') 6
# ('M38', 'M18') 6
# ('M60', 'M36') 4
# ('M89', 'M58') 4
# ('M74', 'M50') 4
# ('M66', 'M30') 5
# ('M37', 'M60') 4
# ('M45', 'M72') 4
# ('M79', 'M98') 6
# ('M70', 'M2') 7
# ('M22', 'M1') 6
# ('M68', 'M91') 5
# ('M80', 'M35') 4
# ('M68', 'M11') 4
# ('M50', 'M25') 4
# ('M37', 'M9') 5
# ('M55', 'M83') 4
# ('M10', 'M32') 4
# ('M45', 'M38') 9
# ('M76', 'M71') 6
# ('M28', 'M3') 4
# ('M47', 'M84') 4
# ('M84', 'M2') 5
# ('M52', 'M43') 4
# ('M92', 'M42') 4
# ('M84', 'M6') 7
# ('M72', 'M84') 4
# ('M13', 'M98') 5
# ('M10', 'M94') 4
# ('M10', 'M27') 4
# ('M25', 'M6') 4
# ('M41', 'M15') 6
# ('M8', 'M11') 5
# ('M91', 'M17') 4
# ('M37', 'M22') 6
# ('M80', 'M25') 6
# ('M63', 'M29') 4
# ('M72', 'M2') 6
# ('M56', 'M22') 5
# ('M98', 'M32') 5
# ('M74', 'M98') 5
# ('M50', 'M8') 5
# ('M71', 'M92') 4
# ('M3', 'M15') 10
# ('M11', 'M83') 4
# ('M49', 'M30') 4
# ('M8', 'M1') 5
# ('M20', 'M27') 4
# ('M10', 'M88') 6
# ('M98', 'M27') 4
# ('M68', 'M3') 7
# ('M27', 'M32') 7
# ('M93', 'M12') 5
# ('M50', 'M43') 4
# ('M98', 'M78') 5
# ('M51', 'M95') 5
# ('M10', 'M68') 5
# ('M14', 'M11') 5
# ('M59', 'M76') 5
# ('M59', 'M15') 7
# ('M61', 'M32') 6
# ('M43', 'M42') 4
# ('M99', 'M30') 4
# ('M47', 'M10') 4
# ('M10', 'M8') 4
# ('M92', 'M3') 6
# ('M14', 'M1') 4
# ('M67', 'M84') 7
# ('M24', 'M83') 6
# ('M22', 'M89') 6
# ('M9', 'M57') 4
# ('M27', 'M78') 6
# ('M5', 'M42') 4
# ('M9', 'M15') 7
# ('M61', 'M78') 5
# ('M79', 'M71') 4
# ('M32', 'M57') 4
# ('M56', 'M50') 6
# ('M67', 'M2') 4
# ('M49', 'M61') 4
# ('M24', 'M11') 4
# ('M84', 'M66') 5
# ('M61', 'M25') 5
# ('M68', 'M89') 4
# ('M49', 'M18') 4
# ('M5', 'M11') 4
# ('M23', 'M3') 4
# ('M50', 'M29') 4
# ('M33', 'M21') 4
# ('M84', 'M17') 4
# ('M23', 'M14') 5
# ('M86', 'M95') 4
# ('M61', 'M68') 7
# ('M91', 'M58') 5
# ('M10', 'M46') 4
# ('M72', 'M53') 6
# ('M89', 'M1') 5
# ('M69', 'M64') 4
# ('M41', 'M70') 4
# ('M74', 'M72') 7
# ('M90', 'M26') 4
# ('M45', 'M95') 4
# ('M61', 'M8') 5
# ('M37', 'M98') 4
# ('M70', 'M31') 4
# ('M27', 'M77') 4
# ('M10', 'M73') 4
# ('M24', 'M3') 8
# ('M19', 'M89') 5
# ('M98', 'M46') 5
# ('M36', 'M48') 4
# ('M60', 'M54') 4
# ('M68', 'M87') 5
# ('M17', 'M57') 4
# ('M10', 'M29') 4
# ('M71', 'M14') 4
# ('M57', 'M3') 4
# ('M61', 'M43') 8
# ('M26', 'M16') 4
# ('M99', 'M32') 4
# ('M18', 'M32') 10
# ('M33', 'M11') 4
# ('M20', 'M73') 4
# ('M37', 'M93') 7
# ('M98', 'M73') 5
# ('M94', 'M6') 4
# ('M93', 'M27') 10
# ('M91', 'M92') 5
# ('M78', 'M2') 5
# ('M76', 'M56') 5
# ('M92', 'M87') 5
# ('M33', 'M64') 5
# ('M61', 'M46') 4
# ('M98', 'M29') 7
# ('M65', 'M78') 9
# ('M3', 'M26') 4
# ('M98', 'M77') 9
# ('M48', 'M16') 4
# ('M51', 'M32') 4
# ('M1', 'M46') 5
# ('M60', 'M11') 4
# ('M10', 'M83') 5
# ('M27', 'M73') 4
# ('M7', 'M35') 4
# ('M95', 'M66') 5
# ('M80', 'M67') 4
# ('M99', 'M25') 6
# ('M65', 'M9') 6
# ('M10', 'M97') 4
# ('M18', 'M25') 6
# ('M51', 'M35') 5
# ('M11', 'M87') 4
# ('M61', 'M73') 5
# ('M27', 'M29') 5
# ('M63', 'M70') 5
# ('M93', 'M9') 4
# ('M14', 'M87') 4
# ('M61', 'M13') 4
# ('M95', 'M17') 4
# ('M61', 'M21') 5
# ('M99', 'M68') 4
# ('M38', 'M91') 4
# ('M53', 'M30') 4
# ('M8', 'M63') 4
# ('M51', 'M47') 5
# ('M45', 'M18') 4
# ('M37', 'M72') 9
# ('M10', 'M1') 8
# ('M38', 'M67') 7
# ('M48', 'M2') 4
# ('M10', 'M15') 4
# ('M66', 'M92') 7
# ('M8', 'M84') 4
# ('M67', 'M9') 4
# ('M67', 'M31') 5
# ('M87', 'M73') 4
# ('M12', 'M6') 8
# ('M79', 'M2') 8
# ('M77', 'M6') 5
# ('M37', 'M38') 7
# ('M55', 'M2') 5
# ('M62', 'M28') 5
# ('M87', 'M29') 4
# ('M80', 'M3') 5
# ('M95', 'M9') 4
# ('M24', 'M87') 4
# ('M62', 'M91') 4
# ('M44', 'M80') 4
# ('M77', 'M30') 4
# ('M61', 'M83') 5
# ('M20', 'M1') 4
# ('M99', 'M43') 4
# ('M51', 'M8') 5
# ('M74', 'M95') 5
# ('M59', 'M48') 4
# ('M84', 'M92') 5
# ('M45', 'M35') 4
# ('M14', 'M84') 6
# ('M54', 'M5') 4
# ('M38', 'M3') 4
# ('M21', 'M27') 5
# ('M25', 'M92') 4
# ('M27', 'M57') 4
# ('M74', 'M2') 8
# ('M27', 'M15') 5
# ('M72', 'M92') 4
# ('M18', 'M75') 4
# ('M28', 'M27') 4
# ('M91', 'M3') 5
# ('M23', 'M55') 9
# ('M61', 'M15') 9
# ('M59', 'M56') 6
# ('M65', 'M5') 4
# ('M65', 'M73') 8
# ('M9', 'M2') 8
# ('M9', 'M6') 5
# ('M21', 'M25') 5
# ('M80', 'M89') 5
# ('M28', 'M78') 7
# ('M24', 'M63') 4
# ('M32', 'M2') 5
# ('M61', 'M20') 6
# ('M89', 'M63') 4
# ('M34', 'M83') 5
# ('M64', 'M2') 4
# ('M93', 'M29') 6
# ('M5', 'M63') 4
# ('M63', 'M2') 7
# ('M28', 'M25') 6
# ('M22', 'M27') 5
# ('M79', 'M61') 4
# ('M69', 'M63') 4
# ('M62', 'M14') 4
# ('M99', 'M13') 4
# ('M94', 'M31') 4
# ('M89', 'M84') 8
# ('M99', 'M21') 5
# ('M18', 'M77') 4
# ('M50', 'M87') 4
# ('M87', 'M15') 7
# ('M69', 'M84') 4
# ('M69', 'M12') 6
# ('M24', 'M90') 4
# ('M71', 'M55') 4
# ('M84', 'M11') 5
# ('M45', 'M8') 7
# ('M51', 'M73') 4
# ('M59', 'M80') 7
# ('M79', 'M66') 4
# ('M10', 'M70') 4
# ('M53', 'M35') 7
# ('M51', 'M13') 4
# ('M92', 'M32') 4
# ('M60', 'M87') 4
# ('M66', 'M3') 11
# ('M68', 'M78') 4
# ('M74', 'M61') 4
# ('M99', 'M83') 5
# ('M18', 'M83') 4
# ('M6', 'M2') 4
# ('M59', 'M66') 5
# ('M17', 'M2') 5
# ('M77', 'M35') 9
# ('M17', 'M6') 8
# ('M37', 'M95') 4
# ('M22', 'M8') 4
# ('M56', 'M95') 5
# ('M28', 'M7') 4
# ('M74', 'M66') 5
# ('M24', 'M10') 6
# ('M38', 'M87') 4
# ('M14', 'M32') 4
# ('M46', 'M73') 4
# ('M88', 'M20') 4
# ('M50', 'M84') 5
# ('M50', 'M12') 5
# ('M76', 'M99') 5
# ('M18', 'M64') 4
# ('M56', 'M2') 4
# ('M93', 'M15') 5
# ('M56', 'M6') 6
# ('M9', 'M66') 6
# ('M83', 'M2') 8
# ('M23', 'M27') 6
# ('M99', 'M15') 7
# ('M14', 'M27') 9
# ('M86', 'M92') 5
# ('M51', 'M11') 4
# ('M9', 'M17') 7
# ('M49', 'M14') 4
# ('M63', 'M53') 5
# ('M14', 'M78') 6
# ('M51', 'M67') 6
# ('M18', 'M20') 4
# ('M80', 'M84') 8
# ('M71', 'M32') 5
# ('M22', 'M46') 6
# ('M33', 'M56') 5
# ('M51', 'M15') 4
# ('M13', 'M25') 4
# ('M5', 'M32') 6
# ('M14', 'M9') 9
# ('M38', 'M63') 4
# ('M71', 'M27') 7
# ('M35', 'M73') 4
# ('M68', 'M46') 5
# ('M9', 'M31') 4
# ('M5', 'M27') 6
# ('M35', 'M29') 5
# ('M69', 'M27') 4
# ('M24', 'M78') 4
# ('M32', 'M31') 5
# ('M22', 'M29') 5
# ('M66', 'M87') 7
# ('M89', 'M78') 4
# ('M26', 'M73') 5
# ('M56', 'M61') 4
# ('M10', 'M56') 5
# ('M98', 'M48') 4
# ('M5', 'M25') 4
# ('M54', 'M70') 4
# ('M98', 'M2') 11
# ('M33', 'M24') 4
# ('M45', 'M91') 4
# ('M60', 'M10') 4
# ('M28', 'M97') 4
# ('M62', 'M30') 4
# ('M45', 'M67') 4
# ('M67', 'M14') 4
# ('M14', 'M7') 4
# ('M56', 'M66') 4
# ('M84', 'M87') 5
# ('M73', 'M15') 6
# ('M61', 'M84') 4
# ('M65', 'M70') 4
# ('M6', 'M35') 6
# ('M21', 'M15') 4
# ('M62', 'M45') 7
# ('M50', 'M53') 4
# ('M84', 'M16') 4
# ('M61', 'M48') 5
# ('M5', 'M8') 4
# ('M12', 'M92') 4
# ('M28', 'M15') 6
# ('M51', 'M79') 6
# ('M1', 'M2') 8
# ('M37', 'M35') 4
# ('M33', 'M78') 4
# ('M53', 'M83') 5
# ('M14', 'M50') 4
# ('M22', 'M15') 6
# ('M60', 'M27') 6
# ('M14', 'M77') 4
# ('M37', 'M47') 4
# ('M89', 'M46') 6
# ('M80', 'M78') 6
# ('M38', 'M32') 6
# ('M5', 'M46') 6
# ('M50', 'M68') 7
# ('M68', 'M15') 4
# ('M60', 'M25') 5
# ('M84', 'M30') 5
# ('M51', 'M87') 4
# ('M33', 'M51') 4
# ('M48', 'M11') 5
# ('M91', 'M32') 6
# ('M38', 'M94') 4
# ('M38', 'M27') 6
# ('M90', 'M1') 4
# ('M20', 'M53') 4
# ('M25', 'M30') 7
# ('M80', 'M9') 6
# ('M84', 'M55') 4
# ('M89', 'M73') 8
# ('M57', 'M73') 5
# ('M24', 'M29') 4
# ('M60', 'M68') 5
# ('M8', 'M15') 8
# ('M69', 'M50') 4
# ('M91', 'M35') 4
# ('M37', 'M8') 4
# ('M38', 'M78') 4
# ('M62', 'M32') 5
# ('M98', 'M17') 4
# ('M45', 'M89') 7
# ('M13', 'M83') 5
# ('M88', 'M2') 6
# ('M99', 'M63') 4
# ('M69', 'M29') 4
# ('M59', 'M28') 6
# ('M37', 'M52') 4
# ('M5', 'M77') 4
# ('M69', 'M77') 5
# ('M62', 'M35') 4
# ('M99', 'M84') 4
# ('M18', 'M84') 5
# ('M52', 'M29') 4
# ('M59', 'M91') 4
# ('M74', 'M28') 5
# ('M61', 'M53') 4
# ('M97', 'M83') 4
# ('M93', 'M2') 4
# ('M41', 'M72') 4
# ('M93', 'M6') 5
# ('M11', 'M15') 4
# ('M9', 'M66', 'M25') 4
# ('M23', 'M50', 'M27') 4
# ('M37', 'M72', 'M83') 5
# ('M47', 'M70', 'M3') 4
# ('M79', 'M98', 'M29') 5
# ('M9', 'M73', 'M16') 5
# ('M18', 'M25', 'M32') 4
# ('M17', 'M11', 'M6') 7
# ('M24', 'M10', 'M72') 5
# ('M61', 'M17', 'M43') 5
# ('M9', 'M11', 'M2') 4
# ('M63', 'M53', 'M35') 5
# ('M77', 'M2', 'M29') 5
# ('M22', 'M89', 'M46') 5
# ('M65', 'M9', 'M73') 5
# ('M77', 'M6', 'M35') 5
# ('M17', 'M11', 'M2') 4
# ('M79', 'M98', 'M2') 5
# ('M63', 'M87', 'M35') 5
# ('M69', 'M6', 'M35') 5
# ('M37', 'M74', 'M72') 4
# ('M28', 'M66', 'M25') 5
# ('M79', 'M98', 'M77') 5
# ('M80', 'M28', 'M66') 6
# ('M68', 'M87', 'M3') 5
# ('M38', 'M18', 'M32') 5
# ('M9', 'M91', 'M27') 5
# ('M98', 'M77', 'M2') 6
# ('M56', 'M50', 'M68') 5
# ('M60', 'M14', 'M53') 6
# ('M38', 'M67', 'M32') 5
# ('M59', 'M56', 'M15') 5
# ('M60', 'M50', 'M68') 5
# ('M98', 'M77', 'M29') 5
# ('M62', 'M38', 'M29') 5
# ('M56', 'M50', 'M92') 5
# ('M24', 'M72', 'M83') 5
# ('M38', 'M84', 'M32') 5
# ('M80', 'M9', 'M66') 4
# ('M66', 'M92', 'M87') 5
# ('M72', 'M53', 'M87') 5
# ('M12', 'M6', 'M35') 5
# ('M65', 'M3', 'M16') 5
# ('M59', 'M56', 'M78') 5
# ('M14', 'M9', 'M27') 6
# ('M45', 'M93', 'M29') 5
# ('M72', 'M63', 'M35') 5
# ('M61', 'M11', 'M43') 5
# ('M67', 'M32', 'M31') 4
# ('M68', 'M92', 'M87') 5
# ('M74', 'M47', 'M72') 5
# ('M59', 'M78', 'M3') 5
# ('M14', 'M48', 'M84') 5
# ('M5', 'M93', 'M32') 5
# ('M45', 'M70', 'M15') 5
# ('M60', 'M50', 'M92') 5
# ('M28', 'M66', 'M30') 5
# ('M41', 'M8', 'M15') 4
# ('M66', 'M87', 'M3') 5
# ('M89', 'M84', 'M73') 6
# ('M10', 'M72', 'M83') 5
# ('M45', 'M8', 'M63') 4
# ('M28', 'M25', 'M30') 5
# ('M24', 'M3', 'M2') 4
# ('M37', 'M5', 'M32') 5
# ('M45', 'M2', 'M15') 4
# ('M69', 'M77', 'M6') 5
# ('M78', 'M3', 'M15') 6
# ('M62', 'M38', 'M93') 5
# ('M65', 'M73', 'M16') 5
# ('M23', 'M76', 'M71') 4
# ('M22', 'M1', 'M46') 5
# ('M23', 'M76', 'M99') 4
# ('M65', 'M3', 'M73') 5
# ('M79', 'M77', 'M29') 5
# ('M67', 'M18', 'M84') 5
# ('M37', 'M24', 'M72') 6
# ('M14', 'M22', 'M9') 5
# ('M99', 'M61', 'M25') 4
# ('M37', 'M70', 'M15') 4
# ('M37', 'M93', 'M27') 6
# ('M62', 'M45', 'M73') 4
# ('M37', 'M27', 'M32') 5
# ('M22', 'M9', 'M91') 5
# ('M37', 'M2', 'M15') 4
# ('M8', 'M70', 'M15') 4
# ('M44', 'M89', 'M84') 5
# ('M51', 'M74', 'M72') 5
# ('M45', 'M8', 'M15') 5
# ('M51', 'M47', 'M72') 5
# ('M79', 'M77', 'M2') 5
# ('M60', 'M14', 'M48') 5
# ('M61', 'M78', 'M15') 4
# ('M61', 'M21', 'M25') 4
# ('M45', 'M63', 'M15') 4
# ('M62', 'M45', 'M38') 5
# ('M28', 'M9', 'M66') 4
# ('M72', 'M87', 'M35') 5
# ('M33', 'M89', 'M58') 4
# ('M44', 'M45', 'M89') 5
# ('M66', 'M78', 'M3') 4
# ('M59', 'M78', 'M15') 5
# ('M12', 'M77', 'M6') 5
# ('M61', 'M17', 'M6') 5
# ('M13', 'M84', 'M6') 4
# ('M72', 'M53', 'M35') 5
# ('M45', 'M38', 'M73') 4
# ('M22', 'M89', 'M2') 5
# ('M68', 'M66', 'M87') 5
# ('M88', 'M66', 'M3') 4
# ('M22', 'M2', 'M46') 6
# ('M14', 'M84', 'M53') 5
# ('M80', 'M9', 'M25') 4
# ('M14', 'M22', 'M27') 5
# ('M59', 'M3', 'M15') 7
# ('M68', 'M66', 'M92') 7
# ('M14', 'M91', 'M27') 5
# ('M80', 'M28', 'M25') 5
# ('M89', 'M1', 'M46') 5
# ('M45', 'M38', 'M15') 4
# ('M53', 'M87', 'M35') 5
# ('M13', 'M83', 'M6') 4
# ('M14', 'M93', 'M9') 4
# ('M1', 'M2', 'M46') 5
# ('M11', 'M6', 'M43') 5
# ('M9', 'M17', 'M11') 4
# ('M22', 'M89', 'M1') 5
# ('M8', 'M63', 'M15') 4
# ('M80', 'M28', 'M30') 5
# ('M91', 'M78', 'M15') 4
# ('M9', 'M3', 'M73') 6
# ('M5', 'M93', 'M27') 5
# ('M84', 'M83', 'M6') 4
# ('M14', 'M93', 'M27') 4
# ('M60', 'M48', 'M53') 6
# ('M69', 'M77', 'M35') 5
# ('M22', 'M9', 'M15') 4
# ('M61', 'M6', 'M43') 5
# ('M45', 'M89', 'M84') 5
# ('M44', 'M84', 'M73') 5
# ('M37', 'M65', 'M3') 4
# ('M93', 'M27', 'M32') 6
# ('M45', 'M84', 'M73') 6
# ('M9', 'M66', 'M3') 4
# ('M92', 'M87', 'M3') 5
# ('M68', 'M84', 'M92') 4
# ('M61', 'M11', 'M6') 5
# ('M60', 'M14', 'M84') 5
# ('M56', 'M78', 'M3') 5
# ('M5', 'M27', 'M32') 5
# ('M62', 'M93', 'M29') 5
# ('M37', 'M5', 'M27') 5
# ('M45', 'M84', 'M15') 4
# ('M60', 'M56', 'M50') 5
# ('M44', 'M89', 'M73') 5
# ('M80', 'M66', 'M25') 5
# ('M37', 'M70', 'M2') 4
# ('M62', 'M45', 'M29') 5
# ('M99', 'M71', 'M15') 5
# ('M89', 'M2', 'M46') 5
# ('M69', 'M12', 'M6') 5
# ('M67', 'M18', 'M32') 5
# ('M22', 'M1', 'M2') 5
# ('M37', 'M10', 'M83') 5
# ('M66', 'M3', 'M73') 4
# ('M56', 'M22', 'M91') 4
# ('M28', 'M78', 'M3') 4
# ('M12', 'M77', 'M35') 5
# ('M44', 'M45', 'M84') 6
# ('M80', 'M66', 'M30') 5
# ('M17', 'M11', 'M43') 5
# ('M50', 'M27', 'M55') 4
# ('M56', 'M68', 'M92') 6
# ('M66', 'M3', 'M15') 4
# ('M50', 'M68', 'M92') 6
# ('M37', 'M5', 'M93') 5
# ('M45', 'M38', 'M29') 5
# ('M9', 'M3', 'M16') 5
# ('M67', 'M84', 'M32') 5
# ('M69', 'M12', 'M77') 5
# ('M22', 'M91', 'M15') 4
# ('M60', 'M68', 'M92') 5
# ('M62', 'M45', 'M93') 5
# ('M60', 'M56', 'M68') 5
# ('M62', 'M28', 'M15') 4
# ('M14', 'M9', 'M91') 5
# ('M28', 'M9', 'M30') 4
# ('M24', 'M10', 'M83') 5
# ('M45', 'M71', 'M15') 4
# ('M14', 'M48', 'M53') 5
# ('M89', 'M1', 'M2') 5
# ('M99', 'M61', 'M21') 4
# ('M37', 'M24', 'M10') 5
# ('M56', 'M78', 'M15') 5
# ('M48', 'M84', 'M53') 5
# ('M79', 'M2', 'M29') 6
# ('M76', 'M99', 'M71') 4
# ('M38', 'M93', 'M29') 5
# ('M68', 'M92', 'M3') 5
# ('M91', 'M3', 'M15') 4
# ('M79', 'M9', 'M73') 4
# ('M22', 'M9', 'M27') 5
# ('M99', 'M21', 'M25') 4
# ('M23', 'M50', 'M55') 4
# ('M60', 'M56', 'M92') 5
# ('M37', 'M10', 'M38') 4
# ('M38', 'M18', 'M84') 5
# ('M63', 'M53', 'M87') 5
# ('M45', 'M38', 'M93') 5
# ('M70', 'M2', 'M15') 6
# ('M38', 'M67', 'M84') 5
# ('M45', 'M89', 'M73') 5
# ('M98', 'M2', 'M29') 5
# ('M66', 'M92', 'M3') 5
# ('M38', 'M67', 'M18') 5
# ('M86', 'M95', 'M15') 4
# ('M28', 'M66', 'M78') 4
# ('M56', 'M3', 'M15') 5
# ('M66', 'M57', 'M3') 4
# ('M23', 'M99', 'M71') 4
# ('M69', 'M12', 'M35') 5
# ('M65', 'M9', 'M16') 5
# ('M9', 'M17', 'M2') 4
# ('M18', 'M84', 'M32') 5
# ('M44', 'M45', 'M73') 5
# ('M3', 'M73', 'M16') 5
# ('M65', 'M9', 'M3') 5
# ('M72', 'M63', 'M87') 5
# ('M74', 'M95', 'M8') 4
# ('M60', 'M84', 'M53') 5
# ('M66', 'M25', 'M30') 5
# ('M37', 'M10', 'M72') 7
# ('M59', 'M56', 'M3') 5
# ('M14', 'M22', 'M91') 5
# ('M60', 'M48', 'M84') 6
# ('M37', 'M24', 'M83') 5
# ('M41', 'M47', 'M72') 4
# ('M17', 'M6', 'M43') 5
# ('M51', 'M74', 'M47') 5
# ('M35', 'M73', 'M29') 4
# ('M13', 'M84', 'M83') 4
# ('M80', 'M25', 'M30') 5
# ('M72', 'M63', 'M53') 5
# ('M61', 'M17', 'M11') 5
# ('M37', 'M93', 'M32') 5
# ('M7', 'M77', 'M35') 4
# ('M68', 'M66', 'M3') 5
# ('M22', 'M91', 'M27') 5
# ('M37', 'M10', 'M87') 4
# Runtime: 2549.509469270706 seconds

# %%
start_time = time.time()
df = pd.read_csv('transactionlarge.csv', header=None)

data_set = []
for index, row in df.iterrows():
    data_row = []
    for value in row.values:
        if str(value) != 'nan':
            data_row.append(value)
    data_set.append(data_row)

te = TransactionEncoder()
te_array = te.fit(data_set).transform(data_set)

data_frame = pd.DataFrame(te_array, columns=te.columns_)
apriori_frequent_item_sets(data_frame, 5, 3)
print(f'Runtime: {time.time() - start_time} seconds')
# Out:
# ('M49') 20
# ('M23') 23
# ('M37') 34
# ('M44') 21
# ('M59') 27
# ('M69') 23
# ('M62') 27
# ('M33') 20
# ('M45') 34
# ('M51') 31
# ('M79') 26
# ('M80') 27
# ('M76') 24
# ('M60') 28
# ('M65') 23
# ('M74') 32
# ('M24') 26
# ('M41') 22
# ('M47') 21
# ('M19') 17
# ('M10') 35
# ('M99') 24
# ('M54') 23
# ('M71') 23
# ('M38') 31
# ('M56') 36
# ('M67') 24
# ('M14') 30
# ('M88') 21
# ('M94') 21
# ('M50') 29
# ('M28') 30
# ('M18') 28
# ('M5') 29
# ('M61') 36
# ('M36') 16
# ('M52') 23
# ('M13') 18
# ('M68') 29
# ('M86') 20
# ('M95') 25
# ('M90') 22
# ('M21') 22
# ('M85') 8
# ('M7') 18
# ('M75') 17
# ('M22') 27
# ('M34') 18
# ('M93') 32
# ('M9') 30
# ('M89') 26
# ('M8') 30
# ('M98') 31
# ('M72') 31
# ('M91') 34
# ('M97') 19
# ('M20') 22
# ('M48') 21
# ('M84') 39
# ('M66') 30
# ('M25') 26
# ('M17') 27
# ('M82') 19
# ('M27') 38
# ('M1') 28
# ('M64') 20
# ('M81') 18
# ('M96') 15
# ('M78') 31
# ('M12') 23
# ('M92') 31
# ('M40') 19
# ('M55') 32
# ('M4') 19
# ('M77') 31
# ('M63') 29
# ('M32') 32
# ('M57') 25
# ('M53') 23
# ('M11') 28
# ('M83') 31
# ('M6') 36
# ('M87') 29
# ('M43') 22
# ('M70') 24
# ('M31') 23
# ('M42') 19
# ('M58') 17
# ('M3') 35
# ('M30') 31
# ('M2') 41
# ('M46') 26
# ('M26') 14
# ('M35') 30
# ('M73') 33
# ('M15') 40
# ('M16') 19
# ('M29') 32
# ('M61', 'M17') 7
# ('M14', 'M15') 6
# ('M32', 'M42') 7
# ('M77', 'M3') 5
# ('M51', 'M84') 5
# ('M9', 'M91') 8
# ('M67', 'M6') 6
# ('M66', 'M27') 5
# ('M66', 'M78') 7
# ('M62', 'M8') 5
# ('M24', 'M15') 5
# ('M84', 'M32') 5
# ('M56', 'M92') 7
# ('M95', 'M30') 5
# ('M57', 'M15') 5
# ('M66', 'M25') 6
# ('M25', 'M32') 5
# ('M60', 'M29') 5
# ('M52', 'M93') 5
# ('M84', 'M27') 6
# ('M69', 'M62') 5
# ('M88', 'M66') 6
# ('M51', 'M74') 6
# ('M8', 'M70') 7
# ('M45', 'M63') 6
# ('M84', 'M78') 7
# ('M60', 'M65') 5
# ('M51', 'M10') 5
# ('M72', 'M35') 5
# ('M53', 'M87') 6
# ('M38', 'M73') 5
# ('M38', 'M5') 5
# ('M84', 'M25') 5
# ('M17', 'M11') 9
# ('M38', 'M29') 8
# ('M28', 'M84') 5
# ('M93', 'M17') 5
# ('M67', 'M18') 5
# ('M91', 'M29') 5
# ('M78', 'M6') 5
# ('M56', 'M91') 6
# ('M13', 'M70') 6
# ('M62', 'M5') 5
# ('M62', 'M29') 7
# ('M22', 'M2') 7
# ('M80', 'M15') 5
# ('M68', 'M84') 5
# ('M7', 'M78') 5
# ('M73', 'M16') 6
# ('M44', 'M45') 7
# ('M59', 'M16') 5
# ('M57', 'M70') 5
# ('M74', 'M87') 6
# ('M37', 'M3') 7
# ('M40', 'M15') 5
# ('M56', 'M3') 9
# ('M77', 'M63') 6
# ('M3', 'M2') 8
# ('M56', 'M14') 5
# ('M6', 'M73') 6
# ('M61', 'M98') 8
# ('M8', 'M2') 5
# ('M28', 'M61') 5
# ('M98', 'M57') 5
# ('M9', 'M16') 6
# ('M91', 'M15') 8
# ('M84', 'M73') 7
# ('M62', 'M15') 6
# ('M28', 'M66') 9
# ('M25', 'M73') 6
# ('M11', 'M2') 11
# ('M11', 'M6') 10
# ('M10', 'M72') 8
# ('M14', 'M48') 5
# ('M14', 'M2') 5
# ('M67', 'M52') 5
# ('M10', 'M38') 8
# ('M74', 'M30') 5
# ('M94', 'M27') 6
# ('M74', 'M55') 7
# ('M71', 'M84') 5
# ('M9', 'M30') 6
# ('M66', 'M15') 7
# ('M84', 'M83') 9
# ('M5', 'M12') 5
# ('M28', 'M9') 6
# ('M24', 'M2') 7
# ('M9', 'M55') 5
# ('M89', 'M2') 7
# ('M37', 'M87') 6
# ('M70', 'M15') 9
# ('M76', 'M8') 5
# ('M72', 'M91') 5
# ('M7', 'M77') 6
# ('M93', 'M98') 6
# ('M51', 'M21') 5
# ('M90', 'M27') 8
# ('M24', 'M56') 5
# ('M38', 'M70') 5
# ('M22', 'M9') 8
# ('M84', 'M15') 5
# ('M12', 'M35') 6
# ('M63', 'M15') 8
# ('M70', 'M3') 6
# ('M14', 'M53') 6
# ('M47', 'M72') 10
# ('M93', 'M91') 6
# ('M68', 'M22') 6
# ('M83', 'M6') 5
# ('M72', 'M3') 5
# ('M45', 'M73') 11
# ('M60', 'M84') 9
# ('M9', 'M32') 5
# ('M45', 'M29') 7
# ('M60', 'M48') 7
# ('M56', 'M55') 6
# ('M80', 'M48') 5
# ('M88', 'M3') 6
# ('M9', 'M35') 5
# ('M9', 'M27') 6
# ('M74', 'M47') 7
# ('M63', 'M35') 8
# ('M10', 'M2') 6
# ('M38', 'M84') 6
# ('M60', 'M56') 6
# ('M44', 'M73') 5
# ('M9', 'M25') 5
# ('M99', 'M71') 7
# ('M74', 'M68') 5
# ('M37', 'M74') 5
# ('M14', 'M22') 6
# ('M37', 'M10') 8
# ('M45', 'M97') 5
# ('M74', 'M8') 7
# ('M62', 'M84') 5
# ('M90', 'M73') 5
# ('M51', 'M71') 5
# ('M86', 'M15') 7
# ('M22', 'M98') 5
# ('M98', 'M30') 5
# ('M37', 'M24') 10
# ('M45', 'M15') 12
# ('M17', 'M27') 5
# ('M27', 'M6') 6
# ('M77', 'M73') 6
# ('M28', 'M57') 5
# ('M79', 'M73') 6
# ('M61', 'M2') 5
# ('M37', 'M32') 7
# ('M23', 'M75') 6
# ('M61', 'M6') 7
# ('M72', 'M87') 8
# ('M77', 'M29') 7
# ('M79', 'M29') 7
# ('M12', 'M77') 6
# ('M79', 'M77') 6
# ('M10', 'M61') 7
# ('M60', 'M53') 7
# ('M37', 'M27') 8
# ('M80', 'M66') 9
# ('M94', 'M15') 6
# ('M56', 'M27') 5
# ('M23', 'M50') 5
# ('M80', 'M53') 5
# ('M27', 'M55') 5
# ('M22', 'M93') 6
# ('M73', 'M29') 7
# ('M24', 'M58') 5
# ('M56', 'M78') 9
# ('M31', 'M2') 5
# ('M87', 'M2') 5
# ('M1', 'M55') 7
# ('M56', 'M25') 5
# ('M68', 'M93') 5
# ('M65', 'M16') 6
# ('M78', 'M3') 8
# ('M72', 'M63') 7
# ('M9', 'M73') 7
# ('M56', 'M68') 8
# ('M34', 'M30') 5
# ('M37', 'M51') 6
# ('M71', 'M21') 5
# ('M6', 'M43') 5
# ('M17', 'M43') 5
# ('M90', 'M20') 6
# ('M77', 'M15') 5
# ('M95', 'M87') 6
# ('M91', 'M78') 6
# ('M45', 'M70') 6
# ('M38', 'M31') 5
# ('M37', 'M7') 6
# ('M33', 'M58') 5
# ('M14', 'M93') 5
# ('M59', 'M64') 5
# ('M23', 'M76') 5
# ('M14', 'M91') 7
# ('M32', 'M83') 7
# ('M44', 'M89') 5
# ('M18', 'M30') 6
# ('M91', 'M27') 7
# ('M56', 'M46') 5
# ('M74', 'M15') 5
# ('M61', 'M35') 5
# ('M51', 'M2') 5
# ('M71', 'M93') 5
# ('M59', 'M3') 8
# ('M37', 'M73') 5
# ('M37', 'M5') 5
# ('M71', 'M15') 8
# ('M32', 'M15') 5
# ('M5', 'M93') 8
# ('M37', 'M29') 5
# ('M51', 'M56') 5
# ('M60', 'M50') 7
# ('M84', 'M53') 7
# ('M78', 'M87') 5
# ('M56', 'M21') 6
# ('M87', 'M35') 8
# ('M50', 'M92') 6
# ('M9', 'M3') 7
# ('M99', 'M61') 8
# ('M18', 'M61') 6
# ('M60', 'M92') 6
# ('M99', 'M18') 5
# ('M45', 'M84') 9
# ('M36', 'M84') 5
# ('M37', 'M83') 7
# ('M24', 'M72') 7
# ('M45', 'M2') 6
# ('M21', 'M6') 6
# ('M84', 'M31') 5
# ('M10', 'M92') 5
# ('M49', 'M60') 5
# ('M88', 'M27') 5
# ('M17', 'M15') 6
# ('M93', 'M32') 8
# ('M56', 'M64') 6
# ('M28', 'M30') 7
# ('M44', 'M84') 7
# ('M74', 'M70') 5
# ('M3', 'M16') 5
# ('M56', 'M15') 7
# ('M80', 'M28') 8
# ('M67', 'M32') 8
# ('M28', 'M55') 5
# ('M68', 'M2') 6
# ('M41', 'M63') 5
# ('M61', 'M92') 5
# ('M12', 'M63') 5
# ('M38', 'M93') 7
# ('M45', 'M61') 6
# ('M48', 'M84') 8
# ('M63', 'M87') 8
# ('M70', 'M29') 5
# ('M77', 'M2') 7
# ('M62', 'M93') 8
# ('M27', 'M83') 8
# ('M46', 'M35') 5
# ('M60', 'M14') 7
# ('M8', 'M55') 5
# ('M98', 'M1') 5
# ('M72', 'M73') 5
# ('M10', 'M3') 7
# ('M23', 'M6') 6
# ('M13', 'M2') 5
# ('M72', 'M29') 5
# ('M13', 'M6') 5
# ('M74', 'M84') 5
# ('M61', 'M91') 5
# ('M38', 'M72') 6
# ('M61', 'M11') 5
# ('M93', 'M46') 5
# ('M37', 'M70') 7
# ('M81', 'M73') 5
# ('M66', 'M57') 5
# ('M2', 'M46') 8
# ('M61', 'M1') 5
# ('M68', 'M66') 7
# ('M71', 'M6') 6
# ('M68', 'M17') 5
# ('M72', 'M83') 5
# ('M59', 'M74') 5
# ('M2', 'M73') 7
# ('M62', 'M38') 5
# ('M69', 'M6') 7
# ('M61', 'M3') 6
# ('M2', 'M29') 7
# ('M84', 'M57') 6
# ('M71', 'M56') 5
# ('M48', 'M53') 7
# ('M74', 'M10') 5
# ('M51', 'M92') 5
# ('M72', 'M15') 5
# ('M87', 'M3') 8
# ('M74', 'M24') 5
# ('M80', 'M16') 6
# ('M10', 'M87') 6
# ('M47', 'M3') 5
# ('M59', 'M27') 5
# ('M37', 'M2') 7
# ('M59', 'M78') 9
# ('M41', 'M8') 5
# ('M95', 'M97') 5
# ('M2', 'M15') 8
# ('M50', 'M55') 6
# ('M23', 'M31') 7
# ('M79', 'M22') 5
# ('M51', 'M41') 5
# ('M60', 'M30') 5
# ('M65', 'M3') 8
# ('M80', 'M30') 5
# ('M95', 'M15') 6
# ('M24', 'M27') 5
# ('M41', 'M46') 6
# ('M69', 'M35') 8
# ('M47', 'M70') 5
# ('M98', 'M63') 5
# ('M51', 'M72') 6
# ('M45', 'M93') 5
# ('M45', 'M57') 5
# ('M78', 'M83') 5
# ('M11', 'M43') 5
# ('M68', 'M92') 13
# ('M3', 'M73') 7
# ('M3', 'M29') 5
# ('M59', 'M75') 5
# ('M1', 'M63') 5
# ('M11', 'M46') 5
# ('M37', 'M17') 5
# ('M90', 'M98') 6
# ('M78', 'M15') 8
# ('M50', 'M27') 7
# ('M22', 'M91') 8
# ('M30', 'M35') 6
# ('M38', 'M18') 6
# ('M66', 'M30') 5
# ('M79', 'M98') 6
# ('M70', 'M2') 7
# ('M22', 'M1') 6
# ('M68', 'M91') 5
# ('M37', 'M9') 5
# ('M45', 'M38') 9
# ('M76', 'M71') 6
# ('M84', 'M2') 5
# ('M84', 'M6') 7
# ('M13', 'M98') 5
# ('M41', 'M15') 6
# ('M8', 'M11') 5
# ('M37', 'M22') 6
# ('M80', 'M25') 6
# ('M72', 'M2') 6
# ('M56', 'M22') 5
# ('M98', 'M32') 5
# ('M74', 'M98') 5
# ('M50', 'M8') 5
# ('M3', 'M15') 10
# ('M8', 'M1') 5
# ('M10', 'M88') 6
# ('M68', 'M3') 7
# ('M27', 'M32') 7
# ('M93', 'M12') 5
# ('M98', 'M78') 5
# ('M51', 'M95') 5
# ('M10', 'M68') 5
# ('M14', 'M11') 5
# ('M59', 'M76') 5
# ('M59', 'M15') 7
# ('M61', 'M32') 6
# ('M92', 'M3') 6
# ('M67', 'M84') 7
# ('M24', 'M83') 6
# ('M22', 'M89') 6
# ('M27', 'M78') 6
# ('M9', 'M15') 7
# ('M61', 'M78') 5
# ('M56', 'M50') 6
# ('M84', 'M66') 5
# ('M61', 'M25') 5
# ('M23', 'M14') 5
# ('M61', 'M68') 7
# ('M91', 'M58') 5
# ('M72', 'M53') 6
# ('M89', 'M1') 5
# ('M74', 'M72') 7
# ('M61', 'M8') 5
# ('M24', 'M3') 8
# ('M19', 'M89') 5
# ('M98', 'M46') 5
# ('M68', 'M87') 5
# ('M61', 'M43') 8
# ('M18', 'M32') 10
# ('M37', 'M93') 7
# ('M98', 'M73') 5
# ('M93', 'M27') 10
# ('M91', 'M92') 5
# ('M78', 'M2') 5
# ('M76', 'M56') 5
# ('M92', 'M87') 5
# ('M33', 'M64') 5
# ('M98', 'M29') 7
# ('M65', 'M78') 9
# ('M98', 'M77') 9
# ('M1', 'M46') 5
# ('M10', 'M83') 5
# ('M95', 'M66') 5
# ('M99', 'M25') 6
# ('M65', 'M9') 6
# ('M18', 'M25') 6
# ('M51', 'M35') 5
# ('M61', 'M73') 5
# ('M27', 'M29') 5
# ('M63', 'M70') 5
# ('M61', 'M21') 5
# ('M51', 'M47') 5
# ('M37', 'M72') 9
# ('M10', 'M1') 8
# ('M38', 'M67') 7
# ('M66', 'M92') 7
# ('M67', 'M31') 5
# ('M12', 'M6') 8
# ('M79', 'M2') 8
# ('M77', 'M6') 5
# ('M37', 'M38') 7
# ('M55', 'M2') 5
# ('M62', 'M28') 5
# ('M80', 'M3') 5
# ('M61', 'M83') 5
# ('M51', 'M8') 5
# ('M74', 'M95') 5
# ('M84', 'M92') 5
# ('M14', 'M84') 6
# ('M21', 'M27') 5
# ('M74', 'M2') 8
# ('M27', 'M15') 5
# ('M91', 'M3') 5
# ('M23', 'M55') 9
# ('M61', 'M15') 9
# ('M59', 'M56') 6
# ('M65', 'M73') 8
# ('M9', 'M2') 8
# ('M9', 'M6') 5
# ('M21', 'M25') 5
# ('M80', 'M89') 5
# ('M28', 'M78') 7
# ('M32', 'M2') 5
# ('M61', 'M20') 6
# ('M34', 'M83') 5
# ('M93', 'M29') 6
# ('M63', 'M2') 7
# ('M28', 'M25') 6
# ('M22', 'M27') 5
# ('M89', 'M84') 8
# ('M99', 'M21') 5
# ('M87', 'M15') 7
# ('M69', 'M12') 6
# ('M84', 'M11') 5
# ('M45', 'M8') 7
# ('M59', 'M80') 7
# ('M53', 'M35') 7
# ('M66', 'M3') 11
# ('M99', 'M83') 5
# ('M59', 'M66') 5
# ('M17', 'M2') 5
# ('M77', 'M35') 9
# ('M17', 'M6') 8
# ('M56', 'M95') 5
# ('M74', 'M66') 5
# ('M24', 'M10') 6
# ('M50', 'M84') 5
# ('M50', 'M12') 5
# ('M76', 'M99') 5
# ('M93', 'M15') 5
# ('M56', 'M6') 6
# ('M9', 'M66') 6
# ('M83', 'M2') 8
# ('M23', 'M27') 6
# ('M99', 'M15') 7
# ('M14', 'M27') 9
# ('M86', 'M92') 5
# ('M9', 'M17') 7
# ('M63', 'M53') 5
# ('M14', 'M78') 6
# ('M51', 'M67') 6
# ('M80', 'M84') 8
# ('M71', 'M32') 5
# ('M22', 'M46') 6
# ('M33', 'M56') 5
# ('M5', 'M32') 6
# ('M14', 'M9') 9
# ('M71', 'M27') 7
# ('M68', 'M46') 5
# ('M5', 'M27') 6
# ('M35', 'M29') 5
# ('M32', 'M31') 5
# ('M22', 'M29') 5
# ('M66', 'M87') 7
# ('M26', 'M73') 5
# ('M10', 'M56') 5
# ('M98', 'M2') 11
# ('M84', 'M87') 5
# ('M73', 'M15') 6
# ('M6', 'M35') 6
# ('M62', 'M45') 7
# ('M61', 'M48') 5
# ('M28', 'M15') 6
# ('M51', 'M79') 6
# ('M1', 'M2') 8
# ('M53', 'M83') 5
# ('M22', 'M15') 6
# ('M60', 'M27') 6
# ('M89', 'M46') 6
# ('M80', 'M78') 6
# ('M38', 'M32') 6
# ('M5', 'M46') 6
# ('M50', 'M68') 7
# ('M60', 'M25') 5
# ('M84', 'M30') 5
# ('M48', 'M11') 5
# ('M91', 'M32') 6
# ('M38', 'M27') 6
# ('M25', 'M30') 7
# ('M80', 'M9') 6
# ('M89', 'M73') 8
# ('M57', 'M73') 5
# ('M60', 'M68') 5
# ('M8', 'M15') 8
# ('M62', 'M32') 5
# ('M45', 'M89') 7
# ('M13', 'M83') 5
# ('M88', 'M2') 6
# ('M59', 'M28') 6
# ('M69', 'M77') 5
# ('M18', 'M84') 5
# ('M74', 'M28') 5
# ('M93', 'M6') 5
# ('M37', 'M72', 'M83') 5
# ('M79', 'M98', 'M29') 5
# ('M9', 'M73', 'M16') 5
# ('M17', 'M11', 'M6') 7
# ('M24', 'M10', 'M72') 5
# ('M61', 'M17', 'M43') 5
# ('M63', 'M53', 'M35') 5
# ('M77', 'M2', 'M29') 5
# ('M22', 'M89', 'M46') 5
# ('M65', 'M9', 'M73') 5
# ('M77', 'M6', 'M35') 5
# ('M79', 'M98', 'M2') 5
# ('M63', 'M87', 'M35') 5
# ('M69', 'M6', 'M35') 5
# ('M28', 'M66', 'M25') 5
# ('M79', 'M98', 'M77') 5
# ('M80', 'M28', 'M66') 6
# ('M68', 'M87', 'M3') 5
# ('M38', 'M18', 'M32') 5
# ('M9', 'M91', 'M27') 5
# ('M98', 'M77', 'M2') 6
# ('M56', 'M50', 'M68') 5
# ('M60', 'M14', 'M53') 6
# ('M38', 'M67', 'M32') 5
# ('M59', 'M56', 'M15') 5
# ('M60', 'M50', 'M68') 5
# ('M98', 'M77', 'M29') 5
# ('M62', 'M38', 'M29') 5
# ('M56', 'M50', 'M92') 5
# ('M24', 'M72', 'M83') 5
# ('M38', 'M84', 'M32') 5
# ('M66', 'M92', 'M87') 5
# ('M72', 'M53', 'M87') 5
# ('M12', 'M6', 'M35') 5
# ('M65', 'M3', 'M16') 5
# ('M59', 'M56', 'M78') 5
# ('M14', 'M9', 'M27') 6
# ('M45', 'M93', 'M29') 5
# ('M72', 'M63', 'M35') 5
# ('M61', 'M11', 'M43') 5
# ('M68', 'M92', 'M87') 5
# ('M74', 'M47', 'M72') 5
# ('M59', 'M78', 'M3') 5
# ('M14', 'M48', 'M84') 5
# ('M5', 'M93', 'M32') 5
# ('M45', 'M70', 'M15') 5
# ('M60', 'M50', 'M92') 5
# ('M28', 'M66', 'M30') 5
# ('M66', 'M87', 'M3') 5
# ('M89', 'M84', 'M73') 6
# ('M10', 'M72', 'M83') 5
# ('M28', 'M25', 'M30') 5
# ('M37', 'M5', 'M32') 5
# ('M69', 'M77', 'M6') 5
# ('M78', 'M3', 'M15') 6
# ('M62', 'M38', 'M93') 5
# ('M65', 'M73', 'M16') 5
# ('M22', 'M1', 'M46') 5
# ('M65', 'M3', 'M73') 5
# ('M79', 'M77', 'M29') 5
# ('M67', 'M18', 'M84') 5
# ('M37', 'M24', 'M72') 6
# ('M14', 'M22', 'M9') 5
# ('M37', 'M93', 'M27') 6
# ('M37', 'M27', 'M32') 5
# ('M22', 'M9', 'M91') 5
# ('M44', 'M89', 'M84') 5
# ('M51', 'M74', 'M72') 5
# ('M45', 'M8', 'M15') 5
# ('M51', 'M47', 'M72') 5
# ('M79', 'M77', 'M2') 5
# ('M60', 'M14', 'M48') 5
# ('M62', 'M45', 'M38') 5
# ('M72', 'M87', 'M35') 5
# ('M44', 'M45', 'M89') 5
# ('M59', 'M78', 'M15') 5
# ('M12', 'M77', 'M6') 5
# ('M61', 'M17', 'M6') 5
# ('M72', 'M53', 'M35') 5
# ('M22', 'M89', 'M2') 5
# ('M68', 'M66', 'M87') 5
# ('M22', 'M2', 'M46') 6
# ('M14', 'M84', 'M53') 5
# ('M14', 'M22', 'M27') 5
# ('M59', 'M3', 'M15') 7
# ('M68', 'M66', 'M92') 7
# ('M14', 'M91', 'M27') 5
# ('M80', 'M28', 'M25') 5
# ('M89', 'M1', 'M46') 5
# ('M53', 'M87', 'M35') 5
# ('M1', 'M2', 'M46') 5
# ('M11', 'M6', 'M43') 5
# ('M22', 'M89', 'M1') 5
# ('M80', 'M28', 'M30') 5
# ('M5', 'M93', 'M27') 5
# ('M60', 'M48', 'M53') 6
# ('M69', 'M77', 'M35') 5
# ('M61', 'M6', 'M43') 5
# ('M45', 'M89', 'M84') 5
# ('M44', 'M84', 'M73') 5
# ('M93', 'M27', 'M32') 6
# ('M45', 'M84', 'M73') 6
# ('M92', 'M87', 'M3') 5
# ('M61', 'M11', 'M6') 5
# ('M60', 'M14', 'M84') 5
# ('M56', 'M78', 'M3') 5
# ('M5', 'M27', 'M32') 5
# ('M62', 'M93', 'M29') 5
# ('M37', 'M5', 'M27') 5
# ('M60', 'M56', 'M50') 5
# ('M44', 'M89', 'M73') 5
# ('M80', 'M66', 'M25') 5
# ('M62', 'M45', 'M29') 5
# ('M99', 'M71', 'M15') 5
# ('M89', 'M2', 'M46') 5
# ('M69', 'M12', 'M6') 5
# ('M67', 'M18', 'M32') 5
# ('M22', 'M1', 'M2') 5
# ('M37', 'M10', 'M83') 5
# ('M12', 'M77', 'M35') 5
# ('M44', 'M45', 'M84') 6
# ('M80', 'M66', 'M30') 5
# ('M17', 'M11', 'M43') 5
# ('M56', 'M68', 'M92') 6
# ('M50', 'M68', 'M92') 6
# ('M37', 'M5', 'M93') 5
# ('M45', 'M38', 'M29') 5
# ('M9', 'M3', 'M16') 5
# ('M67', 'M84', 'M32') 5
# ('M69', 'M12', 'M77') 5
# ('M60', 'M68', 'M92') 5
# ('M62', 'M45', 'M93') 5
# ('M60', 'M56', 'M68') 5
# ('M14', 'M9', 'M91') 5
# ('M24', 'M10', 'M83') 5
# ('M14', 'M48', 'M53') 5
# ('M89', 'M1', 'M2') 5
# ('M37', 'M24', 'M10') 5
# ('M56', 'M78', 'M15') 5
# ('M48', 'M84', 'M53') 5
# ('M79', 'M2', 'M29') 6
# ('M38', 'M93', 'M29') 5
# ('M68', 'M92', 'M3') 5
# ('M22', 'M9', 'M27') 5
# ('M60', 'M56', 'M92') 5
# ('M38', 'M18', 'M84') 5
# ('M63', 'M53', 'M87') 5
# ('M45', 'M38', 'M93') 5
# ('M9', 'M3', 'M73') 6
# ('M70', 'M2', 'M15') 6
# ('M38', 'M67', 'M84') 5
# ('M45', 'M89', 'M73') 5
# ('M98', 'M2', 'M29') 5
# ('M66', 'M92', 'M3') 5
# ('M38', 'M67', 'M18') 5
# ('M56', 'M3', 'M15') 5
# ('M69', 'M12', 'M35') 5
# ('M65', 'M9', 'M16') 5
# ('M18', 'M84', 'M32') 5
# ('M44', 'M45', 'M73') 5
# ('M3', 'M73', 'M16') 5
# ('M65', 'M9', 'M3') 5
# ('M72', 'M63', 'M87') 5
# ('M60', 'M84', 'M53') 5
# ('M66', 'M25', 'M30') 5
# ('M37', 'M10', 'M72') 7
# ('M59', 'M56', 'M3') 5
# ('M14', 'M22', 'M91') 5
# ('M60', 'M48', 'M84') 6
# ('M37', 'M24', 'M83') 5
# ('M17', 'M6', 'M43') 5
# ('M51', 'M74', 'M47') 5
# ('M80', 'M25', 'M30') 5
# ('M72', 'M63', 'M53') 5
# ('M61', 'M17', 'M11') 5
# ('M37', 'M93', 'M32') 5
# ('M68', 'M66', 'M3') 5
# ('M22', 'M91', 'M27') 5
# Runtime: 2373.0204396247864 seconds

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
import time

start_time = time.time()
df = pd.read_csv('transactionlarge.csv', header=None)

data_set = []
for index, row in df.iterrows():
    data_row = []
    for value in row.values:
        if str(value) != 'nan':
            data_row.append(value)
    data_set.append(data_row)

te = TransactionEncoder()
te_array = te.fit(data_set).transform(data_set)

data_frame = pd.DataFrame(te_array, columns=te.columns_)

frequent_itemsets = apriori(data_frame, min_support=0.01, use_colnames=True, max_len=3)
print(frequent_itemsets)
print(f'Runtime: {time.time()}')
# Out:
#        support         itemsets
# 0     0.073333             (M0)
# 1     0.093333             (M1)
# 2     0.116667            (M10)
# 3     0.093333            (M11)
# 4     0.076667            (M12)
# ...        ...              ...
# 2677  0.013333   (M74, M95, M8)
# 2678  0.010000  (M74, M89, M84)
# 2679  0.016667  (M98, M79, M77)
# 2680  0.010000  (M91, M93, M87)
# 2681  0.010000   (M91, M93, M9)
#
# [2682 rows x 2 columns]
# Runtime: 1604719445.2395966

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
import time

start_time = time.time()
df = pd.read_csv('transactionlarge.csv', header=None)

data_set = []
for index, row in df.iterrows():
    data_row = []
    for value in row.values:
        if str(value) != 'nan':
            data_row.append(value)
    data_set.append(data_row)

te = TransactionEncoder()
te_array = te.fit(data_set).transform(data_set)

data_frame = pd.DataFrame(te_array, columns=te.columns_)

frequent_itemsets = apriori(data_frame, min_support=0.013, use_colnames=True, max_len=3)
print(frequent_itemsets)
print(f'Runtime: {time.time()}')
# Out:
#        support         itemsets
# 0     0.073333             (M0)
# 1     0.093333             (M1)
# 2     0.116667            (M10)
# 3     0.093333            (M11)
# 4     0.076667            (M12)
# ...        ...              ...
# 1390  0.013333  (M99, M76, M71)
# 1391  0.013333   (M73, M79, M9)
# 1392  0.020000  (M73, M89, M84)
# 1393  0.013333   (M74, M95, M8)
# 1394  0.016667  (M98, M79, M77)
#
# [1395 rows x 2 columns]
# Runtime: 1604719615.8989446

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
import time

start_time = time.time()
df = pd.read_csv('transactionlarge.csv', header=None)

data_set = []
for index, row in df.iterrows():
    data_row = []
    for value in row.values:
        if str(value) != 'nan':
            data_row.append(value)
    data_set.append(data_row)

te = TransactionEncoder()
te_array = te.fit(data_set).transform(data_set)

data_frame = pd.DataFrame(te_array, columns=te.columns_)

frequent_itemsets = apriori(data_frame, min_support=0.0167, use_colnames=True, max_len=3)
print(frequent_itemsets)
print(f'Runtime: {time.time()}')
# Out:
#       support         itemsets
# 0    0.073333             (M0)
# 1    0.093333             (M1)
# 2    0.116667            (M10)
# 3    0.093333            (M11)
# 4    0.076667            (M12)
# ..        ...              ...
# 412  0.020000  (M48, M60, M84)
# 413  0.020000  (M92, M68, M50)
# 414  0.020000  (M92, M68, M56)
# 415  0.023333  (M92, M68, M66)
# 416  0.020000  (M73, M89, M84)
#
# [417 rows x 2 columns]
# Runtime: 1604719671.9467382
